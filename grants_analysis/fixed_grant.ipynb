# %%
import os
import pandas as pd
import numpy as np

import re
from rapidfuzz import fuzz, process
from tqdm import tqdm

from IPython.display import display

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
grants_path = r'C:\Projects\connecteddatahub\data\grants\cleaned_grants_2010_2018.csv'
affiliation_path = r'C:\Projects\connecteddatahub\data\maps\cleaned_affiliation.csv'
diversity_path = r"C:\Projects\connecteddatahub\data\external\university_enrollment_race.csv"

# %%
grants_df = pd.read_csv(grants_path)
grants_df['Year'] = grants_df['year']
grants_df['Year'] = grants_df['Year'].astype(str)
print(grants_df.shape)
# Out:
# (9262582, 11)

# %%
affiliation_df = pd.read_csv(affiliation_path)
print(affiliation_df.head(4))
print(grants_df.columns)
# Out:
#    AffiliationId  carnegie_id  PrimarySample                  FullName  \
# 0       71965598     188429.0           True        Adelphi University
# 1      181401687     131159.0           True       American University
# 2      102298084     168740.0           True        Andrews University
# 3           1000          NaN           True  Arizona Board of Regents
#
#    SystemId
# 0       NaN
# 1       NaN
# 2       NaN
# 3    1000.0
# Index(['year', 'recip_ein', 'recip_name', 'recip_city', 'recip_state',
#        'recip_zip', 'amount', 'recip_status', 'text', 'type', 'Year'],
#       dtype='object')

# %%
diversity_df = pd.read_csv(diversity_path)
diversity_df = diversity_df.rename(columns={'year': 'Year'})
diversity_df['Year'] = diversity_df['Year'].astype(str)
print(diversity_df.columns)
#merge the number of students into the df
# Out:
# Index(['carnegie_id', 'AffiliationId', 'Year', 'student.size',
#        'student.enrollment.all', 'student.demographics.race_ethnicity.white',
#        'student.demographics.race_ethnicity.black',
#        'student.demographics.race_ethnicity.hispanic',
#        'student.demographics.race_ethnicity.asian',
#        'student.demographics.race_ethnicity.aian',
#        'student.demographics.race_ethnicity.nhpi',
#        'student.demographics.race_ethnicity.two_or_more',
#        'student.demographics.race_ethnicity.non_resident_alien',
#        'student.demographics.race_ethnicity.unknown',
#        'student.demographics.race_ethnicity.white_non_hispanic',
#        'student.demographics.race_ethnicity.black_non_hispanic',
#        'student.demographics.race_ethnicity.asian_pacific_islander',
#        'student.demographics.race_ethnicity.aian_prior_2009',
#        'student.demographics.race_ethnicity.hispanic_prior_2009',
#        'student.demographics.race_ethnicity.unknown_2000',
#        'student.demographics.race_ethnicity.white_2000',
#        'student.demographics.race_ethnicity.black_2000',
#        'student.demographics.race_ethnicity.api_2000',
#        'student.demographics.race_ethnicity.aian_2000',
#        'student.demographics.race_ethnicity.hispanic_2000'],
#       dtype='object')

# %%
years = ["1999", "2000", "2002", "2005", "2007", "2008", "2009", "2010", "2011", "2013", "2018"]

year_df = pd.DataFrame({'Year': years})
affiliation_years = affiliation_df.merge(year_df, how = 'cross')
print(affiliation_years.columns)
# Out:
# Index(['AffiliationId', 'carnegie_id', 'PrimarySample', 'FullName', 'SystemId',
#        'Year'],
#       dtype='object')

# %%
#merge the student sizes into the year df

merged_df = affiliation_years.merge(
    diversity_df[['AffiliationId', 'Year', 'student.size']],
    how = "left",
    on = ["AffiliationId", 'Year']
)

print(merged_df.head(10))
affiliation_years = merged_df
# Out:
#    AffiliationId  carnegie_id  PrimarySample            FullName  SystemId  \
# 0       71965598     188429.0           True  Adelphi University       NaN
# 1       71965598     188429.0           True  Adelphi University       NaN
# 2       71965598     188429.0           True  Adelphi University       NaN
# 3       71965598     188429.0           True  Adelphi University       NaN
# 4       71965598     188429.0           True  Adelphi University       NaN
# 5       71965598     188429.0           True  Adelphi University       NaN
# 6       71965598     188429.0           True  Adelphi University       NaN
# 7       71965598     188429.0           True  Adelphi University       NaN
# 8       71965598     188429.0           True  Adelphi University       NaN
# 9       71965598     188429.0           True  Adelphi University       NaN
#
#    Year  student.size
# 0  1999           NaN
# 1  2000           NaN
# 2  2002        3726.0
# 3  2005        4718.0
# 4  2007        4973.0
# 5  2008        4933.0
# 6  2009        4923.0
# 7  2010           NaN
# 8  2011        5006.0
# 9  2013        5000.0

# %%
def normalize_institution(name: str):
    """Lowercase, strip punctuation, preserve institutional terms."""
    if pd.isna(name):
        return ""
    name = name.lower()
    name = re.sub(r"[^\w\s]", "", name)
    name = re.sub(r"\s+", " ", name).strip()
    return name

grants_df["recip_name_norm"] = grants_df["recip_name"].apply(normalize_institution)
affiliation_years["fullname_norm"] = affiliation_years["FullName"].apply(normalize_institution)

#TF-IDF + cosine similarity
def match_names_discriminative(sub_aff, grants_sub, threshold=0.55):
    """
    Performs institutional name matching using TF-IDF + cosine similarity,    """
    if grants_sub.empty or sub_aff.empty:
        sub_aff["matched_name"] = None
        sub_aff["match_score"] = np.nan
        return sub_aff

    # Build vector space model
    vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(3,6))
    X = vectorizer.fit_transform(grants_sub["recip_name_norm"])
    Y = vectorizer.transform(sub_aff["fullname_norm"])

    # Compute cosine similarities
    sims = cosine_similarity(Y, X)
    best_idx = sims.argmax(axis=1)
    best_score = sims.max(axis=1)

    matched = []
    for i, row in enumerate(sub_aff["fullname_norm"]):
        candidate = grants_sub.iloc[best_idx[i]]["recip_name_norm"]
        score = best_score[i]

        if score < threshold:
            matched.append(None)
            continue

        tokens_row = row.split()
        tokens_cand = candidate.split()
        if not tokens_row or not tokens_cand:
            matched.append(None)
            continue

        # Longest word overlap requirement
        longest_token = max(tokens_row, key=len)
        if longest_token not in tokens_cand:
            matched.append(None)
            continue

        # First token overlap requirement
        first_token = tokens_row[0]
        if first_token not in tokens_cand:
            matched.append(None)
            continue

        matched.append(candidate)

    sub_aff["matched_name"] = matched
    sub_aff["match_score"] = best_score
    return sub_aff


matched_chunks = []
years_iter = sorted(affiliation_years["Year"].dropna().unique())

for yr in tqdm(years_iter, desc="Matching by year"):
    grants_subset = grants_df[grants_df["Year"] == yr]
    sub_aff = affiliation_years[affiliation_years["Year"] == yr].copy()
    matched_chunks.append(match_names_discriminative(sub_aff, grants_subset, threshold=0.55))

affiliation_years = pd.concat(matched_chunks, ignore_index=True)


merged = affiliation_years.merge(
    grants_df[["recip_name_norm", "Year", "amount"]],
    how="left",
    left_on=["matched_name", "Year"],
    right_on=["recip_name_norm", "Year"],
)

grant_stats = (
    merged.groupby(["FullName", "Year"], as_index=False)
    .agg(
        num_grants=("amount", "count"),
        total_funding=("amount", "sum"),
        student_size = ("student.size", "first")
    )
)

affiliation_years = affiliation_years.merge(grant_stats, on=["FullName", "Year"], how="left")
affiliation_years["num_grants"] = affiliation_years["num_grants"].fillna(0).astype(int)
affiliation_years["total_funding"] = affiliation_years["total_funding"].fillna(0.0)
# Out:
# Matching by year: 100%|██████████| 11/11 [07:14<00:00, 39.51s/it]

# %%
print(affiliation_years.columns)
# Out:
# Index(['AffiliationId', 'carnegie_id', 'PrimarySample', 'FullName', 'SystemId',
#        'Year', 'student.size', 'fullname_norm', 'matched_name', 'match_score',
#        'num_grants', 'total_funding', 'student_size'],
#       dtype='object')

# %%
grant_stats_filtered = affiliation_years[affiliation_years["Year"].astype(int) >= 2010]

grant_stats_filtered_interpolate = grant_stats_filtered.sort_values(["FullName", "Year"])

# Interpolate within each AffiliationId across years
grant_stats_filtered_interpolate["student.size"] = (
    grant_stats_filtered_interpolate.groupby("AffiliationId")["student.size"]
    .transform(lambda s: s.interpolate(method="linear"))
    .fillna(
        grant_stats_filtered_interpolate.groupby("AffiliationId")["student.size"].transform("mean")
    )
)

grant_stats_filtered_interpolate = grant_stats_filtered_interpolate.drop('student_size', axis = 1, errors = "ignore")
# grant_stats_filtered_interpolate = grant_stats.sort_values(by = ['FullName', 'Year'])
grant_stats_filtered_interpolate.to_csv(r'C:\Projects\connecteddatahub\data\grants\university_grants.csv', index = False)

# %%
def preview_matches(affiliation_years, grants_df, top_n=20):
    """Show a sample of institution matches by year."""
    # Keep only rows with successful matches
    matched = affiliation_years[affiliation_years["matched_name"].notna()].copy()

    # Merge to bring grant data and similarity if you stored it
    matched = matched.merge(
        grants_df[["recip_name_norm", "Year", "recip_name"]],
        how="left",
        left_on=["matched_name", "Year"],
        right_on=["recip_name_norm", "Year"],
    )

    # Show counts
    print(f"✅ Total matches found: {len(matched):,}")
    print(f"✅ Years matched: {matched['Year'].nunique()}\n")

    # Print a few random or top examples per year
    for yr in sorted(matched['Year'].unique()):
        print(f"\n===== Year {yr} =====")
        sub = matched[matched["Year"] == yr].sample(
            n=min(top_n, len(matched[matched["Year"] == yr])), random_state=42
        )
        display(
            sub[
                [
                    "FullName",
                    "matched_name",
                    "recip_name",   # original name from grants_df
                    "num_grants",
                    "total_funding",
                ]
            ].head(top_n)
        )

# Example usage
preview_matches(affiliation_years, grants_df, top_n = 50)
# Out:
# ✅ Total matches found: 90,600
# ✅ Years matched: 4
#
#
# ===== Year 2010 =====
#                                                 FullName  \
# 11833                  University of Southern California
# 7039                                   Temple University
# 8614                               University of Chicago
# 3798                                   Lehigh University
# 9303                       University of Illinois System
# 1562                                 Columbia University
# 5683                       Pennsylvania State University
# 9549                              University of Kentucky
# 9313                       University of Illinois System
# 3781                                   Lehigh University
# 12813                           University of Washington
# 4630                                 New York University
# 10765         University of North Carolina at Greensboro
# 14142                                    Yale University
# 13670                 Washington University in St. Louis
# 9430                   University of Illinois at Chicago
# 12979                  University of Wisconsin Milwaukee
# 1247                            Clark Atlanta University
# 1053                          Carnegie Mellon University
# 168                                Ball State University
# 2348                                     Duke University
# 4464                               University of Montana
# 2662                                  Fordham University
# 4162                           Michigan State University
# 11791                        University of South Florida
# 10297                      University of Missouri System
# 3562                            Johns Hopkins University
# 2816                    The George Washington University
# 4238                           Michigan State University
# 6071                                   Purdue University
# 2473                                    Emory University
# 1087                     Case Western Reserve University
# 10149                             University of Michigan
# 8814                           University of Connecticut
# 13434                   Virginia Commonwealth University
# 3405                               Iowa State University
# 8390             University of California, San Francisco
# 12730                           University of Washington
# 1730                                  Cornell University
# 11308                           University of Pittsburgh
# 7767                               University of Arizona
# 13814                             Wayne State University
# 5364                  Oregon Health & Science University
# 6423                       Southern Methodist University
# 7791                              University of Arkansas
# 14023                                    Yale University
# 13488  Virginia Polytechnic Institute and State Unive...
# 10369                             University of Missouri
# 6075                                   Purdue University
# 10087                             University of Michigan
#
#                                             matched_name  \
# 11833                  university of southern california
# 7039                                   temple university
# 8614                               university of chicago
# 3798                                   lehigh university
# 9303                              university of illinois
# 1562                                 columbia university
# 5683                       pennsylvania state university
# 9549                              university of kentucky
# 9313                              university of illinois
# 3781                                   lehigh university
# 12813                           university of washington
# 4630                                 new york university
# 10765         university of north carolina at greensboro
# 14142                                    yale university
# 13670                  washington university in st louis
# 9430                   university of illinois at chicago
# 12979                  university of wisconsin milwaukee
# 1247                            clark atlanta university
# 1053                          carnegie mellon university
# 168                                ball state university
# 2348                                     duke university
# 4464                               university of montana
# 2662                                  fordham university
# 4162                           michigan state university
# 11791                        university of south florida
# 10297                             university of missouri
# 3562                            johns hopkins university
# 2816                    the george washington university
# 4238                           michigan state university
# 6071                                   purdue university
# 2473                                    emory university
# 1087                     case western reserve university
# 10149                             university of michigan
# 8814                           university of connecticut
# 13434                   virginia commonwealth university
# 3405                               iowa state university
# 8390              university of california san francisco
# 12730                           university of washington
# 1730                                  cornell university
# 11308                           university of pittsburgh
# 7767                               university of arizona
# 13814                             wayne state university
# 5364                    oregon health science university
# 6423                       southern methodist university
# 7791                              university of arkansas
# 14023                                    yale university
# 13488  virginia polytechnic institute and state unive...
# 10369                             university of missouri
# 6075                                   purdue university
# 10087                             university of michigan
#
#                                               recip_name  num_grants  \
# 11833                  UNIVERSITY OF SOUTHERN CALIFORNIA         125
# 7039                                   TEMPLE UNIVERSITY         117
# 8614                               UNIVERSITY OF CHICAGO         198
# 3798                                   LEHIGH UNIVERSITY          70
# 9303                              UNIVERSITY OF ILLINOIS          67
# 1562                                 COLUMBIA UNIVERSITY         153
# 5683                       PENNSYLVANIA STATE UNIVERSITY         116
# 9549                              UNIVERSITY OF KENTUCKY          62
# 9313                              UNIVERSITY OF ILLINOIS          67
# 3781                                   LEHIGH UNIVERSITY          70
# 12813                           UNIVERSITY OF WASHINGTON         292
# 4630                                 NEW YORK UNIVERSITY         169
# 10765         UNIVERSITY OF NORTH CAROLINA AT GREENSBORO           4
# 14142                                    YALE UNIVERSITY         291
# 13670                  WASHINGTON UNIVERSITY IN ST LOUIS          43
# 9430                   UNIVERSITY OF ILLINOIS AT CHICAGO          16
# 12979                  UNIVERSITY OF WISCONSIN MILWAUKEE          16
# 1247                            CLARK ATLANTA UNIVERSITY          13
# 1053                          CARNEGIE MELLON UNIVERSITY          64
# 168                                BALL STATE UNIVERSITY          24
# 2348                                     DUKE UNIVERSITY         257
# 4464                               UNIVERSITY OF MONTANA          29
# 2662                                  FORDHAM UNIVERSITY          33
# 4162                           MICHIGAN STATE UNIVERSITY         140
# 11791                        UNIVERSITY OF SOUTH FLORIDA          41
# 10297                             UNIVERSITY OF MISSOURI          51
# 3562                            JOHNS HOPKINS UNIVERSITY         206
# 2816                    THE GEORGE WASHINGTON UNIVERSITY          13
# 4238                           MICHIGAN STATE UNIVERSITY         140
# 6071                                   PURDUE UNIVERSITY         127
# 2473                                    EMORY UNIVERSITY         131
# 1087                     CASE WESTERN RESERVE UNIVERSITY          81
# 10149                             UNIVERSITY OF MICHIGAN         205
# 8814                           UNIVERSITY OF CONNECTICUT          54
# 13434                   VIRGINIA COMMONWEALTH UNIVERSITY          47
# 3405                               IOWA STATE UNIVERSITY          62
# 8390              UNIVERSITY OF CALIFORNIA SAN FRANCISCO          50
# 12730                           UNIVERSITY OF WASHINGTON         292
# 1730                                  CORNELL UNIVERSITY         194
# 11308                           UNIVERSITY OF PITTSBURGH         194
# 7767                               UNIVERSITY OF ARIZONA          73
# 13814                             WAYNE STATE UNIVERSITY          69
# 5364                    OREGON HEALTH SCIENCE UNIVERSITY          44
# 6423                       SOUTHERN METHODIST UNIVERSITY          93
# 7791                              UNIVERSITY OF ARKANSAS          15
# 14023                                    YALE UNIVERSITY         291
# 13488  VIRGINIA POLYTECHNIC INSTITUTE AND STATE UNIVE...           6
# 10369                             UNIVERSITY OF MISSOURI          51
# 6075                                   PURDUE UNIVERSITY         127
# 10087                             UNIVERSITY OF MICHIGAN         205
#
#        total_funding
# 11833     44180971.0
# 7039       6855908.0
# 8614      34395832.0
# 3798       3689057.0
# 9303      50509661.0
# 1562      23178445.0
# 5683      48353279.0
# 9549       5397535.0
# 9313      50509661.0
# 3781       3689057.0
# 12813     93413435.0
# 4630      37072586.0
# 10765       482214.0
# 14142     66380027.0
# 13670     11143663.0
# 9430       2490242.0
# 12979      8711593.0
# 1247        728010.0
# 1053      20255566.0
# 168       11124678.0
# 2348      56636302.0
# 4464       1282820.0
# 2662       1364332.0
# 4162      58635825.0
# 11791      5008621.0
# 10297     15204380.0
# 3562      65546366.0
# 2816       3638686.0
# 4238      58635825.0
# 6071      82461245.0
# 2473      32296473.0
# 1087      10027846.0
# 10149     60090477.0
# 8814      24282183.0
# 13434      9306995.0
# 3405      58019727.0
# 8390      15993707.0
# 12730     93413435.0
# 1730      24246903.0
# 11308     33116869.0
# 7767      75250403.0
# 13814      4999311.0
# 5364      17546855.0
# 6423       6681827.0
# 7791        847501.0
# 14023     66380027.0
# 13488       572372.0
# 10369     15204380.0
# 6075      82461245.0
# 10087     60090477.0
# ===== Year 2011 =====
#                                          FullName  \
# 21483                             Pace University
# 27575                    University of New Mexico
# 28344                  University of Pennsylvania
# 26813                         University of Miami
# 16733                          Cornell University
# 22108            Rensselaer Polytechnic Institute
# 32154                          Yeshiva University
# 26647         University of Massachusetts Amherst
# 31119                        Villanova University
# 19934                Mississippi State University
# 29924                       University of Vermont
# 23186                         Syracuse University
# 31114                        Villanova University
# 18883                    Johns Hopkins University
# 25234                    University of Cincinnati
# 28423                    University of Pittsburgh
# 32263              University Of Minnesota System
# 25652                      University of Delaware
# 32082                             Yale University
# 19523       Massachusetts Institute of Technology
# 28047                    University of Notre Dame
# 15527          California Institute of Technology
# 25226                       University of Chicago
# 21708                       Pepperdine University
# 22484  Southern Illinois University at Carbondale
# 16298                   Colorado State University
# 31261                      Wake Forest University
# 25344               University of Colorado System
# 30371                    University of Washington
# 18466                           Howard University
# 15755                  Carnegie Mellon University
# 29775                         University of Tulsa
# 19673                            Miami University
# 17592                            Emory University
# 25053                       University of Chicago
# 23295                           Temple University
# 26848                         University of Miami
# 26871                         University of Miami
# 26790                         University of Miami
# 23729                            Tufts University
# 20144                     Montclair State College
# 22471                Southern Illinois University
# 25928                       University of Houston
# 26266                          University of Iowa
# 22332                        St John's University
# 15570         California State University Hayward
# 22738                         Stanford University
# 17120                             Duke University
# 20914                   The Ohio State University
# 20791                     Northwestern University
#
#                                   matched_name  \
# 21483                          pace university
# 27575                 university of new mexico
# 28344               university of pennsylvania
# 26813                      university of miami
# 16733                       cornell university
# 22108         rensselaer polytechnic institute
# 32154                       yeshiva university
# 26647      university of massachusetts amherst
# 31119                     villanova university
# 19934             mississippi state university
# 29924                    university of vermont
# 23186                      syracuse university
# 31114                     villanova university
# 18883                 johns hopkins university
# 25234                 university of cincinnati
# 28423                 university of pittsburgh
# 32263                  university of minnesota
# 25652                   university of delaware
# 32082                          yale university
# 19523    massachusetts institute of technology
# 28047                 university of notre dame
# 15527       california institute of technology
# 25226                    university of chicago
# 21708                    pepperdine university
# 22484  southern illinois university carbondale
# 16298                colorado state university
# 31261                   wake forest university
# 25344                   university of colorado
# 30371                 university of washington
# 18466                        howard university
# 15755               carnegie mellon university
# 29775                      university of tulsa
# 19673                         miami university
# 17592                         emory university
# 25053                    university of chicago
# 23295                        temple university
# 26848                      university of miami
# 26871                      university of miami
# 26790                      university of miami
# 23729                         tufts university
# 20144                          montclair state
# 22471             southern illinois university
# 25928                    university of houston
# 26266                       university of iowa
# 22332                      st johns university
# 15570              california state university
# 22738                      stanford university
# 17120                          duke university
# 20914                the ohio state university
# 20791                  northwestern university
#
#                                     recip_name  num_grants  total_funding
# 21483                          PACE UNIVERSITY          35       650830.0
# 27575                 UNIVERSITY OF NEW MEXICO          55     13567318.0
# 28344               UNIVERSITY OF PENNSYLVANIA         269    104813508.0
# 26813                      UNIVERSITY OF MIAMI         128     41175600.0
# 16733                       CORNELL UNIVERSITY         252     30318594.0
# 22108         RENSSELAER POLYTECHNIC INSTITUTE          44      3731328.0
# 32154                       YESHIVA UNIVERSITY          57     13409027.0
# 26647      UNIVERSITY OF MASSACHUSETTS AMHERST          25      2478503.0
# 31119                     VILLANOVA UNIVERSITY          59      1462702.0
# 19934             MISSISSIPPI STATE UNIVERSITY          36     31094060.0
# 29924                    UNIVERSITY OF VERMONT          61     15907401.0
# 23186                      SYRACUSE UNIVERSITY         114      5927536.0
# 31114                     VILLANOVA UNIVERSITY          59      1462702.0
# 18883                 JOHNS HOPKINS UNIVERSITY         252    103748340.0
# 25234                 UNIVERSITY OF CINCINNATI         102    134211525.0
# 28423                 UNIVERSITY OF PITTSBURGH         217     79651586.0
# 32263                  UNIVERSITY OF MINNESOTA         120    236925781.0
# 25652                   UNIVERSITY OF DELAWARE          70      3832613.0
# 32082                          YALE UNIVERSITY         321     87199681.0
# 19523    MASSACHUSETTS INSTITUTE OF TECHNOLOGY         143    208024414.0
# 28047                 UNIVERSITY OF NOTRE DAME         133     17836864.0
# 15527       CALIFORNIA INSTITUTE OF TECHNOLOGY          71     39484865.0
# 25226                    UNIVERSITY OF CHICAGO         182     33982731.0
# 21708                    PEPPERDINE UNIVERSITY          39      1194138.0
# 22484  SOUTHERN ILLINOIS UNIVERSITY CARBONDALE           6      6916657.0
# 16298                COLORADO STATE UNIVERSITY          74     28297800.0
# 31261                   WAKE FOREST UNIVERSITY          79     16171125.0
# 25344                   UNIVERSITY OF COLORADO          69    109966237.0
# 30371                 UNIVERSITY OF WASHINGTON         375    145267900.0
# 18466                        HOWARD UNIVERSITY          46      6383388.0
# 15755               CARNEGIE MELLON UNIVERSITY          98     18620891.0
# 29775                      UNIVERSITY OF TULSA          33      7252609.0
# 19673                         MIAMI UNIVERSITY          75      1489509.0
# 17592                         EMORY UNIVERSITY         196    131179714.0
# 25053                    UNIVERSITY OF CHICAGO         182     33982731.0
# 23295                        TEMPLE UNIVERSITY          92      8818789.0
# 26848                      UNIVERSITY OF MIAMI         128     41175600.0
# 26871                      UNIVERSITY OF MIAMI         128     41175600.0
# 26790                      UNIVERSITY OF MIAMI         128     41175600.0
# 23729                         TUFTS UNIVERSITY          91     10134327.0
# 20144                          MONTCLAIR STATE           2         3500.0
# 22471             SOUTHERN ILLINOIS UNIVERSITY          15      1625552.0
# 25928                    UNIVERSITY OF HOUSTON          75      7556975.0
# 26266                       UNIVERSITY OF IOWA          99     39075922.0
# 22332                      ST JOHNS UNIVERSITY          23       151385.0
# 15570              CALIFORNIA STATE UNIVERSITY          15      1738780.0
# 22738                      STANFORD UNIVERSITY         304     86058471.0
# 17120                          DUKE UNIVERSITY         309    108792955.0
# 20914                THE OHIO STATE UNIVERSITY          58      3446268.0
# 20791                  NORTHWESTERN UNIVERSITY         257    110019504.0
# ===== Year 2013 =====
#                                            FullName  \
# 48527                      University of Louisville
# 55011                         Washington University
# 46341       University of California, San Francisco
# 46774                      University of Cincinnati
# 36137                             Drexel University
# 50816                    University of Pennsylvania
# 52908                            University of Utah
# 32815                    Baylor College of Medicine
# 36003                             Dartmouth College
# 48818                         University of Memphis
# 55921                            Yeshiva University
# 55174                        Wayne State University
# 35108                           Columbia University
# 51709            University of St. Thomas Minnesota
# 42379  Polytechnic Institute Of New York University
# 40912                       Northeastern University
# 36908                              Emory University
# 45297                         University of Alabama
# 33339                           Brandeis University
# 41181                       Northwestern University
# 45856                University of California Davis
# 45830               University of California, Davis
# 50434                      University of Notre Dame
# 49652                        University of Missouri
# 42804              Rensselaer Polytechnic Institute
# 40071                  Mississippi State University
# 48195                            University of Iowa
# 33311                           Brandeis University
# 44501                  Sam Houston State University
# 34582                              Clark University
# 39032                             Lehigh University
# 32871                             Baylor University
# 46143            University of California Riverside
# 43798                               SUNY Binghamton
# 46970             University of Colorado at Boulder
# 51700            University of St. Thomas Minnesota
# 49168                        University of Michigan
# 49948                      University of New Mexico
# 41333                       Northwestern University
# 32420                           American University
# 37175                            Fordham University
# 33003                                Boston College
# 49625                 University of Missouri System
# 52517                 University of Texas at Dallas
# 54725                   Washington State University
# 50086                      East Carolina University
# 46629                         University of Chicago
# 51607            University of St. Thomas Minnesota
# 43996                      Florida State University
# 50097                      East Carolina University
#
#                                        matched_name  \
# 48527                      university of louisville
# 55011                         washington university
# 46341        university of california san francisco
# 46774                      university of cincinnati
# 36137                             drexel university
# 50816                    university of pennsylvania
# 52908                            university of utah
# 32815                    baylor college of medicine
# 36003                             dartmouth college
# 48818                         university of memphis
# 55921                            yeshiva university
# 55174                        wayne state university
# 35108                           columbia university
# 51709                       university of minnesota
# 42379  polytechnic institute of new york university
# 40912                       northeastern university
# 36908                              emory university
# 45297                         university of alabama
# 33339                           brandeis university
# 41181                       northwestern university
# 45856                university of california davis
# 45830                university of california davis
# 50434                      university of notre dame
# 49652                        university of missouri
# 42804              rensselaer polytechnic institute
# 40071                  mississippi state university
# 48195                            university of iowa
# 33311                           brandeis university
# 44501                  sam houston state university
# 34582                              clark university
# 39032                             lehigh university
# 32871                             baylor university
# 46143            university of california riverside
# 43798                               suny binghamton
# 46970             university of colorado at boulder
# 51700                       university of minnesota
# 49168                        university of michigan
# 49948                      university of new mexico
# 41333                       northwestern university
# 32420                           american university
# 37175                            fordham university
# 33003                                boston college
# 49625                        university of missouri
# 52517                 university of texas at dallas
# 54725                   washington state university
# 50086                      east carolina university
# 46629                         university of chicago
# 51607                       university of minnesota
# 43996                      florida state university
# 50097                      east carolina university
#
#                                          recip_name  num_grants  total_funding
# 48527                      UNIVERSITY OF LOUISVILLE          71     12013358.0
# 55011                         WASHINGTON UNIVERSITY         229     27920201.0
# 46341        UNIVERSITY OF CALIFORNIA SAN FRANCISCO          86     17798036.0
# 46774                      UNIVERSITY OF CINCINNATI         119    104455410.0
# 36137                             DREXEL UNIVERSITY          98      7021199.0
# 50816                    UNIVERSITY OF PENNSYLVANIA         364     41394533.0
# 52908                            UNIVERSITY OF UTAH         200     29285963.0
# 32815                    BAYLOR COLLEGE OF MEDICINE         168     41734549.0
# 36003                             DARTMOUTH COLLEGE         167     13607985.0
# 48818                         UNIVERSITY OF MEMPHIS          26      5242303.0
# 55921                            YESHIVA UNIVERSITY          80     13321728.0
# 55174                        WAYNE STATE UNIVERSITY         105     15837536.0
# 35108                           COLUMBIA UNIVERSITY         335    155728772.0
# 51709                       UNIVERSITY OF MINNESOTA         111    230982269.0
# 42379  POLYTECHNIC INSTITUTE OF NEW YORK UNIVERSITY           8       155430.0
# 40912                       NORTHEASTERN UNIVERSITY         106      6526872.0
# 36908                              EMORY UNIVERSITY         260     54267701.0
# 45297                         UNIVERSITY OF ALABAMA          84      6114146.0
# 33339                           BRANDEIS UNIVERSITY         141      7518456.0
# 41181                       NORTHWESTERN UNIVERSITY         382    347193009.0
# 45856                UNIVERSITY OF CALIFORNIA DAVIS          67     31673831.0
# 45830                UNIVERSITY OF CALIFORNIA DAVIS          67     31673831.0
# 50434                      UNIVERSITY OF NOTRE DAME         186     30551685.0
# 49652                        UNIVERSITY OF MISSOURI          90      9849009.0
# 42804              RENSSELAER POLYTECHNIC INSTITUTE          58      3074513.0
# 40071                  MISSISSIPPI STATE UNIVERSITY          38     27993099.0
# 48195                            UNIVERSITY OF IOWA         127     44028933.0
# 33311                           BRANDEIS UNIVERSITY         141      7518456.0
# 44501                  SAM HOUSTON STATE UNIVERSITY          20       408265.0
# 34582                              CLARK UNIVERSITY          62      2527368.0
# 39032                             LEHIGH UNIVERSITY         118      3720660.0
# 32871                             BAYLOR UNIVERSITY          79     32020565.0
# 46143            UNIVERSITY OF CALIFORNIA RIVERSIDE          18      1312746.0
# 43798                               SUNY BINGHAMTON           6        72262.0
# 46970             UNIVERSITY OF COLORADO AT BOULDER          16      1990445.0
# 51700                       UNIVERSITY OF MINNESOTA         111    230982269.0
# 49168                        UNIVERSITY OF MICHIGAN         371     81197544.0
# 49948                      UNIVERSITY OF NEW MEXICO          59      8293106.0
# 41333                       NORTHWESTERN UNIVERSITY         382    347193009.0
# 32420                           AMERICAN UNIVERSITY          78      3824110.0
# 37175                            FORDHAM UNIVERSITY          72      4776079.0
# 33003                                BOSTON COLLEGE         109     20633073.0
# 49625                        UNIVERSITY OF MISSOURI          90      9849009.0
# 52517                 UNIVERSITY OF TEXAS AT DALLAS          20       553385.0
# 54725                   WASHINGTON STATE UNIVERSITY         130     68777773.0
# 50086                      EAST CAROLINA UNIVERSITY          41      8565734.0
# 46629                         UNIVERSITY OF CHICAGO         273     41919779.0
# 51607                       UNIVERSITY OF MINNESOTA         111    230982269.0
# 43996                      FLORIDA STATE UNIVERSITY         114     46422220.0
# 50097                      EAST CAROLINA UNIVERSITY          41      8565734.0
# ===== Year 2018 =====
#                                       FullName  \
# 76832  University of California, San Francisco
# 58357     California State University East Bay
# 56960                        Baylor University
# 60784                       Cornell University
# 73403                 Florida State University
# 90170                          Yale University
# 67639                 Montana State University
# 70904                     Princeton University
# 60854                       Cornell University
# 90450                       Yeshiva University
# 60175                      Columbia University
# 64032                       Hampton University
# 66327                     Marquette University
# 87833                    Vanderbilt University
# 84086              University of San Francisco
# 59745                   William & Mary College
# 66021                    Loma Linda University
# 58029                         Brown University
# 65069                    Iowa State University
# 57408                        Boston University
# 75230      University of Alabama at Birmingham
# 85499                University of the Pacific
# 78741                      Hartford University
# 80986                   University of Michigan
# 61953                          Duke University
# 82081          North Carolina State University
# 67772              New Mexico State University
# 85795                       University of Utah
# 80813                   University of Michigan
# 80134      University of Massachusetts Amherst
# 90016                          Yale University
# 78968                      University of Idaho
# 79720                   University of Kentucky
# 73783                        Temple University
# 59937         Colorado State University System
# 80428                      University of Miami
# 76391    University of California, Los Angeles
# 78080                   University of Delaware
# 57494           Bowling Green State University
# 66813                        Mercer University
# 67909                      New York University
# 90301                          Yale University
# 61017                       Cornell University
# 74799                        Tulane University
# 89031                    Washington University
# 88277                            Virginia Tech
# 74787                        Tulane University
# 73070                    University at Buffalo
# 86348                 University of Washington
# 65448                 Johns Hopkins University
#
#                                  matched_name  \
# 76832  university of california san francisco
# 58357    california state university east bay
# 56960                       baylor university
# 60784                      cornell university
# 73403                florida state university
# 90170                         yale university
# 67639                montana state university
# 70904                    princeton university
# 60854                      cornell university
# 90450                      yeshiva university
# 60175                     columbia university
# 64032                      hampton university
# 66327                    marquette university
# 87833                   vanderbilt university
# 84086             university of san francisco
# 59745                 college of william mary
# 66021                   loma linda university
# 58029                        brown university
# 65069                   iowa state university
# 57408                       boston university
# 75230     university of alabama at birmingham
# 85499               university of the pacific
# 78741                  university of hartford
# 80986                  university of michigan
# 61953                         duke university
# 82081         north carolina state university
# 67772             new mexico state university
# 85795                      university of utah
# 80813                  university of michigan
# 80134     university of massachusetts amherst
# 90016                         yale university
# 78968                     university of idaho
# 79720                  university of kentucky
# 73783                       temple university
# 59937               colorado state university
# 80428                     university of miami
# 76391    university of california los angeles
# 78080                  university of delaware
# 57494          bowling green state university
# 66813                       mercer university
# 67909                     new york university
# 90301                         yale university
# 61017                      cornell university
# 74799                       tulane university
# 89031                   washington university
# 88277                           virginia tech
# 74787                       tulane university
# 73070                   university at buffalo
# 86348                university of washington
# 65448                johns hopkins university
#
#                                    recip_name  num_grants  total_funding
# 76832  UNIVERSITY OF CALIFORNIA SAN FRANCISCO         123   4.944566e+07
# 58357    CALIFORNIA STATE UNIVERSITY EAST BAY          11   2.034723e+06
# 56960                       BAYLOR UNIVERSITY         141   4.283308e+07
# 60784                      CORNELL UNIVERSITY         549   9.344316e+07
# 73403                FLORIDA STATE UNIVERSITY         186   1.072881e+08
# 90170                         YALE UNIVERSITY         710   1.486961e+08
# 67639                MONTANA STATE UNIVERSITY          80   3.962273e+07
# 70904                    PRINCETON UNIVERSITY         344   2.882792e+07
# 60854                      CORNELL UNIVERSITY         549   9.344316e+07
# 90450                      YESHIVA UNIVERSITY          97   1.097921e+07
# 60175                     COLUMBIA UNIVERSITY         478   1.047283e+08
# 64032                      HAMPTON UNIVERSITY          51   2.507486e+06
# 66327                    MARQUETTE UNIVERSITY         162   1.440359e+07
# 87833                   VANDERBILT UNIVERSITY         331   4.890769e+07
# 84086             UNIVERSITY OF SAN FRANCISCO          75   1.248750e+07
# 59745                 COLLEGE OF WILLIAM MARY          25   7.326960e+05
# 66021                   LOMA LINDA UNIVERSITY          36   4.049883e+06
# 58029                        BROWN UNIVERSITY         372   6.622045e+07
# 65069                   IOWA STATE UNIVERSITY         132   1.270631e+08
# 57408                       BOSTON UNIVERSITY         185   1.649251e+07
# 75230     UNIVERSITY OF ALABAMA AT BIRMINGHAM         104   6.093863e+07
# 85499               UNIVERSITY OF THE PACIFIC          49   3.977808e+06
# 78741                  UNIVERSITY OF HARTFORD          69   2.396697e+06
# 80986                  UNIVERSITY OF MICHIGAN         500   1.204704e+08
# 61953                         DUKE UNIVERSITY         657   1.829898e+09
# 82081         NORTH CAROLINA STATE UNIVERSITY         123   5.101962e+07
# 67772             NEW MEXICO STATE UNIVERSITY          32   1.354924e+07
# 85795                      UNIVERSITY OF UTAH         303   9.206432e+07
# 80813                  UNIVERSITY OF MICHIGAN         500   1.204704e+08
# 80134     UNIVERSITY OF MASSACHUSETTS AMHERST          59   8.628053e+06
# 90016                         YALE UNIVERSITY         710   1.486961e+08
# 78968                     UNIVERSITY OF IDAHO          45   2.529597e+06
# 79720                  UNIVERSITY OF KENTUCKY         148   4.666583e+07
# 73783                       TEMPLE UNIVERSITY         193   2.041264e+07
# 59937               COLORADO STATE UNIVERSITY         112   1.286985e+08
# 80428                     UNIVERSITY OF MIAMI         316   6.149208e+07
# 76391    UNIVERSITY OF CALIFORNIA LOS ANGELES          81   3.781722e+08
# 78080                  UNIVERSITY OF DELAWARE         167   2.953065e+07
# 57494          BOWLING GREEN STATE UNIVERSITY          59   5.520566e+06
# 66813                       MERCER UNIVERSITY          44   2.979279e+06
# 67909                     NEW YORK UNIVERSITY         425   8.884066e+07
# 90301                         YALE UNIVERSITY         710   1.486961e+08
# 61017                      CORNELL UNIVERSITY         549   9.344316e+07
# 74799                       TULANE UNIVERSITY         175   3.111613e+07
# 89031                   WASHINGTON UNIVERSITY         322   1.073189e+08
# 88277                           VIRGINIA TECH          77   3.291402e+07
# 74787                       TULANE UNIVERSITY         175   3.111613e+07
# 73070                   UNIVERSITY AT BUFFALO          16   1.828238e+06
# 86348                UNIVERSITY OF WASHINGTON         458   2.745621e+08
# 65448                JOHNS HOPKINS UNIVERSITY         485   2.133012e+08
