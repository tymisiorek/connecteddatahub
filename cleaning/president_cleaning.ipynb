# %%
import os
import pandas as pd
import numpy as np
from collections import Counter

# %%
data_path = r'C:\Projects\connecteddatahub\data'

years = ["2013"]
years = ["1999","2000","2005","2007","2008","2009","2010","2011","2013","2018",]

president_words = ["president", "chancellor", "superintendent", "commissioner", "officer-in-charge"]

# %%
def count_first_positions(df):
    """
    Check the distribution of positions listed for the first position of each institution.
    Flag institutions whose first position is not 'president' or 'chancellor',
    or contains 'vice president'. Print the institution, flagged position, and original row index.
    Also print full group for 'Queens College'.
    """
    # Get the first row (original index preserved) per institution
    first_row_indices = df.groupby("Institution", sort=False).head(1).index
    first_rows = df.loc[first_row_indices]

    positions = []
    flagged = []

    for idx, row in first_rows.iterrows():
        pos = str(row["Position"]).strip()
        institution = row["Institution"]
        positions.append(pos)

        position_lower = pos.lower()
        if not any(pres in position_lower for pres in president_words) or "vice" in position_lower:
            flagged.append((idx, institution, pos))

    print("\nInstitutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):")
    for idx, inst, pos in flagged:
        print(f" - Index {idx}: {inst} → '{pos}'")

    print("\nCounts of first-row position titles:")
    counts = Counter(positions)
    for title, count in counts.most_common():
        print(f"{title}: {count}")

# %%
for year in years:
    print(f"Processing: {year}")
    gpt_df = pd.read_csv(os.path.join(data_path, 'cleaned_dataframes', 'split_positions', f'{year}_split_positions.csv'))
    count_first_positions(gpt_df)
# Out:
# Processing: 1999
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 4259: Queens College → 'Dean'
#  - Index 6636: Tennessee Board Of Regents → 'Regent'
#  - Index 9010: Institute For Advanced Study → 'Director'
#  - Index 17319: State University Of New York System → 'Trustee'
#  - Index 18277: Texas A&M University Baylor College Of Dentistry → 'Vice President'
#  - Index 18414: Texas A&M University Galveston → 'Vice President'
#
# Counts of first-row position titles:
# President: 547
# Chancellor: 116
# President (Acting): 17
# Chancellor (Acting): 2
# Vice President: 2
# Dean: 1
# President (Until January 1, 1999): 1
# Regent: 1
# Director: 1
# Commissioner of Higher Education: 1
# Acting President: 1
# Trustee: 1
# Acting Chancellor: 1
# Superintendent: 1
# Hudson E. Bridge Chancellor: 1
# Processing: 2000
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 9462: Institute For Advanced Study → 'Director'
#  - Index 19911: Baylor College Of Dentistry → 'Chief Executive Officer'
#  - Index 20050: Texas A&M University Galveston → 'Vice President'
#
# Counts of first-row position titles:
# President: 555
# Chancellor: 120
# President (Acting): 13
# Chancellor (Acting): 5
# Acting President: 1
# Director: 1
# Commissioner of Higher Education: 1
# Chief Executive Officer: 1
# Vice President: 1
# Acting Chancellor: 1
# Superintendent: 1
# Hudson E. Bridge Chancellor: 1
# Processing: 2005
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 10995: Institute For Advanced Study → 'Director'
#  - Index 16487: Oregon University System → 'Executive Vice Chancellor'
#  - Index 22727: Texas A&M University At Galveston → 'Vice President'
#  - Index 23829: United States Coast Guard Academy → 'Dean, Academics'
#  - Index 27882: University Of Minnesota System → 'Regent'
#  - Index 29142: University Of North Texas Dallas Campus → 'Vice Provost'
#
# Counts of first-row position titles:
# President: 570
# Chancellor: 114
# President (Interim): 11
# Chancellor (Interim): 8
# Superintendent: 5
# Commissioner of Higher Education: 2
# Director: 1
# Executive Vice Chancellor: 1
# Vice President: 1
# Dean, Academics: 1
# President (Acting): 1
# Regent: 1
# Vice Provost: 1
# Hudson E. Bridge Chancellor: 1
# Processing: 2007
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 84: Cornell University → 'Trustee'
#  - Index 5537: Cleveland State University → 'Dean'
#  - Index 10707: Illinois State University → 'Director, Honors Program'
#  - Index 10986: Institute For Advanced Study → 'Director'
#  - Index 12530: Louisiana State University → 'Dean'
#  - Index 14315: University Of Mississippi Medical Center → 'Vice Chancellor, Health Affairs'
#  - Index 18361: University Of Pennsylvania → 'Trustee'
#  - Index 22873: Texas A&M University At Galveston → 'Vice President'
#  - Index 29408: University Of North Texas Dallas Campus → 'Vice Provost'
#  - Index 33795: University Of New Hampshire Manchester → 'Dean'
#
# Counts of first-row position titles:
# President: 555
# Chancellor: 116
# President (Interim): 20
# Chancellor (Interim): 7
# Superintendent: 6
# Dean: 3
# Chancellor (Acting): 3
# Trustee: 2
# Commissioner of Higher Education: 2
# President-Elect: 1
# Director, Honors Program: 1
# Director: 1
# Vice Chancellor, Health Affairs: 1
# Officer-In-Charge: 1
# Vice President: 1
# President (Acting): 1
# Vice Provost: 1
# Interim Chancellor: 1
# Processing: 2008
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 11058: Indiana University Bloomington → 'Provost'
#  - Index 11168: Institute For Advanced Study → 'Director'
#  - Index 19560: Rutgers State University Of New Jersey Newark → 'Provost'
#  - Index 23431: Texas A&M University At Galveston → 'Vice President'
#  - Index 29971: University Of North Texas Dallas Campus → 'Vice Provost'
#
# Counts of first-row position titles:
# President: 567
# Chancellor: 116
# President (Interim): 11
# Chancellor (Interim): 10
# Superintendent: 6
# Provost: 2
# Commissioner of Higher Education: 2
# President (Acting): 2
# Chancellor (Acting): 2
# Chancellor, Health Affairs: 1
# Director: 1
# Interim President: 1
# President Interim: 1
# Vice President: 1
# Vice Provost: 1
# Processing: 2009
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 10702: Indiana University Bloomington → 'Provost'
#  - Index 10830: Institute For Advanced Study → 'Director'
#  - Index 19068: Rutgers State University Of New Jersey Newark → 'Provost'
#  - Index 22879: Texas A&M University At Galveston → 'Vice President'
#  - Index 29340: University Of North Texas At Dallas → 'Vice Provost'
#
# Counts of first-row position titles:
# President: 557
# Chancellor: 115
# President (Interim): 19
# Chancellor (Interim): 10
# Superintendent: 5
# Provost: 2
# President (Acting): 2
# Chancellor, Health Affairs: 1
# President Emeritus: 1
# Director: 1
# Commissioner of Higher Education (Interim): 1
# Commissioner of Higher Education: 1
# Interim Chancellor: 1
# Vice President: 1
# Superintendent (Acting): 1
# Vice Provost: 1
# Processing: 2010
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 683: Arizona Board Of Regents → 'Executive Director'
#  - Index 1733: Board Of Regents State Of Iowa → 'Executive Director'
#  - Index 2383: Stanford University → 'Trustee'
#  - Index 3707: California State University Hayward → 'Dean'
#  - Index 6753: Marquette University → 'Director'
#  - Index 9936: Idaho State Board Of Education → 'Executive Director'
#  - Index 10310: Indiana University Bloomington → 'Provost'
#  - Index 10451: Institute For Advanced Study → 'Director'
#  - Index 20342: South Dakota Board Of Regents → 'Executive Director'
#  - Index 23073: Texas A&M University At Galveston → 'Vice President'
#  - Index 28860: University Of North Texas At Dallas → 'Vice Chancellor'
#  - Index 32788: University Of New Hampshire Manchester → 'Dean'
#
# Counts of first-row position titles:
# President: 561
# Chancellor: 123
# President (Interim): 21
# Chancellor (Interim): 6
# Superintendent: 6
# Executive Director: 4
# Dean: 2
# Director: 2
# Commissioner of Higher Education: 2
# Trustee: 1
# Provost: 1
# Vice President: 1
# Vice Chancellor: 1
# Commissioner: 1
# Processing: 2011
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 1712: Board Of Regents State Of Iowa → 'Executive Director'
#  - Index 9788: Idaho State Board Of Education → 'Executive Director'
#  - Index 10135: Indiana University Bloomington → 'Provost'
#  - Index 10271: Institute For Advanced Study → 'Director'
#  - Index 15563: University Of Oklahoma Health Sciences Center → 'Executive Vice President, University Governance'
#  - Index 16227: Clarion University Of Pennsylvania → 'Dean'
#  - Index 19738: South Dakota Board Of Regents → 'Executive Director'
#  - Index 22398: Texas A&M University At Galveston → 'Vice President'
#  - Index 23670: University Of Alabama At Birmingham → 'General Auditor'
#
# Counts of first-row position titles:
# President: 560
# Chancellor: 123
# President (Interim): 24
# Superintendent: 6
# Chancellor (Interim): 5
# Executive Director: 3
# Commissioner of Higher Education: 2
# President (Acting): 1
# Provost: 1
# Director: 1
# University Chancellor: 1
# Executive Vice President, University Governance: 1
# Dean: 1
# Vice President: 1
# General Auditor: 1
# Chancellor (Acting): 1
# Commissioner: 1
# Processing: 2013
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 1223: Board Of Regents State Of Iowa → 'Executive Director'
#  - Index 2218: California Polytechnic State University San Luis Obispo → 'Executive Director'
#  - Index 3192: Case Western Reserve University → 'Trustee'
#  - Index 6234: Gannon University → 'Trustee'
#  - Index 7120: Idaho State Board Of Education → 'Executive Director'
#  - Index 7404: Indiana University Bloomington → 'Provost'
#  - Index 7548: Institute For Advanced Study → 'Director'
#  - Index 15311: South Dakota Board Of Regents → 'Executive Director'
#  - Index 17199: Colgate University → 'Trustee'
#  - Index 18267: Texas Tech University Health Sciences Center At El Paso → 'Founding Dean'
#  - Index 18652: United States Military Academy → 'Chairman'
#  - Index 20665: University Of Illinois At Springfield → 'Vice President'
#  - Index 21931: University Of Minnesota System → 'Regent'
#  - Index 25850: University Of Wisconsin Waukesha → 'Dean'
#  - Index 28436: Wesleyan University → 'Trustee'
#  - Index 28935: Xavier University Of Louisiana → 'Trustee'
#
# Counts of first-row position titles:
# President: 451
# Chancellor: 120
# President (Interim): 21
# Chancellor (Interim): 7
# Trustee: 5
# Executive Director: 4
# President (Acting): 3
# Superintendent: 2
# Commissioner of Higher Education: 2
# Provost: 1
# Director: 1
# Founding Dean: 1
# Chairman: 1
# Interim Chancellor: 1
# Vice President: 1
# Regent: 1
# Dean: 1
# Commissioner: 1
# Processing: 2018
#
# Institutions with flagged positions (no 'President'/'Chancellor' or contains 'Vice President'):
#  - Index 1150: Board Of Regents State Of Iowa → 'Executive Director (Interim)'
#  - Index 3989: Princeton University → 'Trustee'
#  - Index 4782: Marquette University → 'Trustee'
#  - Index 6843: Idaho State Board Of Education → 'Executive Director'
#  - Index 7151: Indiana University Bloomington → 'Executive Vice President'
#  - Index 7311: Institute For Advanced Study → 'Director'
#  - Index 11426: University Of Oklahoma Health Sciences Center → 'Executive Vice President, University Governance'
#  - Index 14535: South Dakota Board Of Regents → 'Executive Director'
#  - Index 16708: Texas A&M Health Science Center → 'Senior Vice President'
#  - Index 16873: Texas A&M University At Galveston → 'Chief Operations Officer'
#  - Index 20868: University Of Minnesota → 'Regent'
#  - Index 24449: University Of Wisconsin Milwaukee → 'Dean'
#  - Index 24610: University Of Wisconsin Waukesha → 'Dean'
#  - Index 26004: University System Of Ohio → 'Ex Officio Regent'
#
# Counts of first-row position titles:
# President: 451
# Chancellor: 115
# President (Interim): 18
# Chancellor (Interim): 11
# President (Acting): 3
# Trustee: 2
# Executive Director: 2
# Commissioner of Higher Education: 2
# Superintendent: 2
# Dean: 2
# Executive Director (Interim): 1
# Executive Vice President: 1
# Director: 1
# Executive Vice President, University Governance: 1
# Senior Vice President: 1
# Chief Operations Officer: 1
# Superintendent and President: 1
# Regent: 1
# Ex Officio Regent: 1
# Commissioner, Academic and Student Affairs: 1

# %%
def mark_president_positions(df: pd.DataFrame):
    """
    Mark rows as 'President' in 'FixedPosition' if we detect a true president
    (president_words, excluding 'vice') in the first row of each institution;
    otherwise, look up to the next 3 rows. Print institutions where we had to
    look further, and those where we found no president in the first 4 rows,
    listing the positions seen.
    
    Returns:
      df               -- original DataFrame with FixedPosition (object dtype) filled in
      president_rows   -- subset DataFrame of the rows marked as President
    """
    # ensure column exists as object dtype
    if "FixedPosition" not in df.columns:
        df["FixedPosition"] = pd.Series([None] * len(df), index=df.index, dtype="object")
    else:
        df["FixedPosition"] = df["FixedPosition"].astype("object")

    def is_true_president(pos):
        pos = str(pos).lower()
        return any(p in pos for p in president_words) and "vice" not in pos

    president_indices = []
    found_late = []    # [(institution, idx, pos), ...]
    not_found = []     # [(institution, [pos1, pos2, pos3, pos4]), ...]

    for inst, group in df.groupby("Institution", sort=False):
        idxs = list(group.index)
        # check first row
        first_idx = idxs[0]
        if is_true_president(df.at[first_idx, "Position"]):
            president_indices.append(first_idx)
            continue

        # look in the next up to 3 rows
        found = False
        for nxt in idxs[1:4]:
            if is_true_president(df.at[nxt, "Position"]):
                president_indices.append(nxt)
                found_late.append((inst, nxt, df.at[nxt, "Position"]))
                found = True
                break
        if not found:
            seen_positions = [str(df.at[i, "Position"]).strip() for i in idxs[:4]]
            not_found.append((inst, seen_positions))

    # Mark the identified rows (no dtype warning now)
    df.loc[president_indices, "FixedPosition"] = "President"
    president_rows = df.loc[president_indices].copy()

    # Print summary
    if found_late:
        print("\nInstitutions where president was found in rows 2–4:")
        for inst, idx, pos in found_late:
            print(f" - {inst}: row {idx} → '{pos}'")

    if not_found:
        print("\nInstitutions with NO president in first 4 rows and their observed positions:")
        for inst, pos_list in not_found:
            joined = ", ".join(f"'{p}'" for p in pos_list)
            print(f" - {inst}: {joined}")

    return df, president_rows

# %%
for year in years:
    print(f"\n\nProcessing: {year}")
    df = pd.read_csv(os.path.join(data_path, 'cleaned_dataframes', 'split_positions', f'{year}_split_positions.csv'))
    full_df, president_df = mark_president_positions(df)
    full_df.to_csv(os.path.join(data_path, 'cleaned_dataframes', f'{year}_cleanedDataframe.csv'), index = False)
    president_df.to_csv(os.path.join(data_path, 'cleaned_dataframes', 'presidents', f'{year}_presidents.csv'), index = False)
# Out:
# Processing: 1999
#
# Institutions where president was found in rows 2–4:
#  - Queens College: row 14322 → 'President'
#  - Tennessee Board Of Regents: row 6638 → 'Chancellor'
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Institute For Advanced Study: 'Director', 'Administrative Officer', 'Administrative Officer', 'Administrative Officer'
#  - State University Of New York System: 'Trustee', 'Trustee', 'Trustee', 'Chairman'
#  - Texas A&M University Baylor College Of Dentistry: 'Vice President', 'Dean (Acting)', 'Vice President, Business Services (Acting)', 'Vice President. Institutional Research and Information Technology Systems'
#  - Texas A&M University Galveston: 'Vice President', 'Chief Executive Officer', 'Executive Associate Vice President', 'Associate Vice President, Student Affairs'
#
#
# Processing: 2000
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Institute For Advanced Study: 'Director', 'Administrative Officer', 'Administrative Officer', 'Administrative Officer'
#  - Baylor College Of Dentistry: 'Chief Executive Officer', 'Dean', 'Associate Dean, Business Services', 'Associate Dean, Institutional Research and Information Technology Systems'
#  - Texas A&M University Galveston: 'Vice President', 'Chief Executive Officer', 'Executive Secretary', 'Executive Associate Vice President'
#
#
# Processing: 2005
#
# Institutions where president was found in rows 2–4:
#  - Oregon University System: row 16489 → 'Chancellor (Acting)'
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Institute For Advanced Study: 'Director', 'Librarian, Historical Studies and Social Science Library', 'Librarian, Math and Natural Science Library', 'Administrative Officer'
#  - Texas A&M University At Galveston: 'Vice President', 'Chief Executive Officer (Interim)', 'Executive Secretary', 'Associate Vice President, Research and Academic Affairs'
#  - United States Coast Guard Academy: 'Dean, Academics', 'Associate Dean', 'Assistant Dean, Academics', 'Commandant of Cadets'
#  - University Of Minnesota System: 'Regent', 'Vice Chairman', 'Regent', 'Regent'
#  - University Of North Texas Dallas Campus: 'Vice Provost', 'Assistant to the Vice Provost', 'Director, Student Services', 'Coordinator, Recruitment and Community Relations'
#
#
# Processing: 2007
#
# Institutions where president was found in rows 2–4:
#  - Cornell University: row 86 → 'President'
#  - University Of Pennsylvania: row 18362 → 'President'
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Cleveland State University: 'Dean', 'Director, Executive MBA', 'Dean', 'Dean'
#  - Illinois State University: 'Director, Honors Program', 'Director, University Marketing and Communications', 'Associate Director, Graduate Studies (Acting)', 'Comptroller'
#  - Institute For Advanced Study: 'Director', 'Associate Director, Development and Public Affairs', 'Associate Director, Finance and Administration', 'Librarian, Historical Studies and Social Science Library'
#  - Louisiana State University: 'Dean', 'Dean', 'Dean', 'Dean'
#  - University Of Mississippi Medical Center: 'Vice Chancellor, Health Affairs', 'Dean, School Of Medicine', 'Associate Vice Chancellor, Research', 'Director, Library and Academic Information Services'
#  - Texas A&M University At Galveston: 'Vice President', 'Chief Executive Officer', 'Executive Secretary', 'Associate Vice President, Academic Affairs'
#  - University Of North Texas Dallas Campus: 'Vice Provost', 'Deputy Vice Provost', 'Director, Student Services', 'Coordinator, Recruitment and Community Relations'
#  - University Of New Hampshire Manchester: 'Dean', 'Library Director'
#
#
# Processing: 2008
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Indiana University Bloomington: 'Provost', 'Executive Vice President', 'Vice Provost, Academic Affairs', 'Dean, Faculties'
#  - Institute For Advanced Study: 'Director', 'Chief Investment Officer', 'Associate Director, Development and Public Affairs', 'Associate Director, Finance and Administration'
#  - Rutgers State University Of New Jersey Newark: 'Provost', 'Associate Provost, Graduate Studies and Enrollment Management', 'Associate Provost, Human Resources', 'Assistant Provost, Administrative Services and Budget'
#  - Texas A&M University At Galveston: 'Vice President', 'Chief Executive Officer', 'Executive Secretary', 'Associate Vice President, Academic Affairs (Interim)'
#  - University Of North Texas Dallas Campus: 'Vice Provost', 'Deputy Vice Provost', 'Director, Student Services', 'Coordinator, Recruitment and Community Relations'
#
#
# Processing: 2009
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Indiana University Bloomington: 'Provost', 'Executive Vice President', 'Vice Provost, Academic Affairs', 'Dean, Faculties'
#  - Institute For Advanced Study: 'Director', 'Chief Investment Officer', 'Associate Director, Development and Public Affairs', 'Associate Director, Finance and Administration'
#  - Rutgers State University Of New Jersey Newark: 'Provost', 'Associate Provost, Graduate Studies and Enrollment Management', 'Associate Provost, Human Resources', 'Assistant Provost, Administrative Services and Budget'
#  - Texas A&M University At Galveston: 'Vice President', 'Chief Executive Officer', 'Executive Secretary', 'Executive Associate Vice President'
#  - University Of North Texas At Dallas: 'Vice Provost', 'Deputy Vice Provost', 'Executive Director, Development', 'Director, Student Services'
#
#
# Processing: 2010
#
# Institutions where president was found in rows 2–4:
#  - Stanford University: row 20700 → 'President'
#  - Marquette University: row 12754 → 'President'
#  - South Dakota Board Of Regents: row 20407 → 'President'
#  - University Of North Texas At Dallas: row 28862 → 'Special Assistant to the President-Designate'
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Arizona Board Of Regents: 'Executive Director', 'Deputy Executive Director and Senior Associate', 'Chief Financial Officer', 'Associate Executive Director, Academic and Student Affairs'
#  - Board Of Regents State Of Iowa: 'Executive Director', 'Chief Business Officer', 'Information Technology Specialist', 'General Counsel'
#  - California State University Hayward: 'Dean'
#  - Idaho State Board Of Education: 'Executive Director', 'Executive Assistant', 'Chief Academic Officer', 'Chief Communications'
#  - Indiana University Bloomington: 'Provost', 'Executive Vice President', 'Vice Provost, Academic Affairs', 'Dean, Faculties'
#  - Institute For Advanced Study: 'Director', 'Chief Investment Officer', 'Associate Director, Development and Public Affairs', 'Associate Director, Finance and Administration'
#  - Texas A&M University At Galveston: 'Vice President', 'Chief Executive Officer (Acting)', 'Executive Secretary', 'Associate Vice President, Academic Affairs'
#  - University Of New Hampshire Manchester: 'Dean'
#
#
# Processing: 2011
#
# Institutions where president was found in rows 2–4:
#  - Clarion University Of Pennsylvania: row 16228 → 'President'
#  - University Of Alabama At Birmingham: row 23671 → 'President'
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Board Of Regents State Of Iowa: 'Executive Director', 'Chief Business Officer', 'Information Technology Specialist', 'General Counsel'
#  - Idaho State Board Of Education: 'Executive Director', 'Executive Assistant', 'Chief Academic Officer', 'Chief Communications'
#  - Indiana University Bloomington: 'Provost', 'Executive Vice President', 'Vice Provost, Faculty and Academic Affairs', 'Vice Provost, Enrollment Management (Interim)'
#  - Institute For Advanced Study: 'Director', 'Chief Investment Officer', 'Associate Director, Development and Public Affairs', 'Associate Director, Finance and Administration'
#  - University Of Oklahoma Health Sciences Center: 'Executive Vice President, University Governance', 'Secretary Of The University', 'Senior Vice President', 'Provost'
#  - South Dakota Board Of Regents: 'Executive Director', 'Vice President, Academic Affairs', 'Vice President, Administration', 'Vice President, Research'
#  - Texas A&M University At Galveston: 'Vice President', 'Chief Executive Officer (Acting)', 'Executive Assistant', 'Associate Vice President, Academic Affairs'
#
#
# Processing: 2013
#
# Institutions where president was found in rows 2–4:
#  - Case Western Reserve University: row 3193 → 'President'
#  - Gannon University: row 6235 → 'President'
#  - University Of Illinois At Springfield: row 20666 → 'Chancellor'
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Board Of Regents State Of Iowa: 'Executive Director', 'Chief Academic Officer', 'Chief Business Officer', 'Regent Communication Officer'
#  - California Polytechnic State University San Luis Obispo: 'Executive Director', 'Associate Vice Presidentcommercial Services', 'Dean', 'Dean'
#  - Idaho State Board Of Education: 'Executive Director', 'Executive Assistant', 'Chief Academic Officer', 'Chief Communications'
#  - Indiana University Bloomington: 'Provost', 'Executive Vice President', 'Vice Provost, Faculty and Academic Affairs', 'Vice Provost, Enrollment Management'
#  - Institute For Advanced Study: 'Director', 'Chief Investment Officer', 'Associate Director, Development and Public Affairs', 'Associate Director, Finance and Administration'
#  - South Dakota Board Of Regents: 'Executive Director', 'Vice President, Academic Affairs', 'Vice President, Finance and Administration', 'General Counsel'
#  - Colgate University: 'Trustee'
#  - Texas Tech University Health Sciences Center At El Paso: 'Founding Dean'
#  - United States Military Academy: 'Chairman', 'Vice Chairman', 'Member', 'Member'
#  - University Of Minnesota System: 'Regent', 'Regent', 'Regent', 'Regent-at-Large'
#  - University Of Wisconsin Waukesha: 'Dean', 'Executive Secretary', 'Associate Dean', 'Assistant Dean, Student Services (Interim)'
#  - Wesleyan University: 'Trustee', 'Trustee', 'Trustee', 'Trustee'
#  - Xavier University Of Louisiana: 'Trustee', 'Trustee'
#
#
# Processing: 2018
#
# Institutions where president was found in rows 2–4:
#  - Princeton University: row 12437 → 'President'
#  - Marquette University: row 8853 → 'President'
#  - University Of Wisconsin Milwaukee: row 24451 → 'Chancellor'
#
# Institutions with NO president in first 4 rows and their observed positions:
#  - Board Of Regents State Of Iowa: 'Executive Director (Interim)', 'Chief Academic Officer', 'Chief Audit Executive', 'Chief Business Officer'
#  - Idaho State Board Of Education: 'Executive Director', 'Executive Assistant', 'Chief Academic Officer', 'Chief Communications'
#  - Indiana University Bloomington: 'Executive Vice President', 'Provost', 'Vice President', 'Director, Intercollegiate Athletics'
#  - Institute For Advanced Study: 'Director', 'Associate Director, Finance And Administration', 'Chief Operating Officer', 'Librarian, Historical Studies and Social Science Library'
#  - University Of Oklahoma Health Sciences Center: 'Executive Vice President, University Governance', 'Secretary Of The University', 'Senior Vice President', 'Provost'
#  - South Dakota Board Of Regents: 'Executive Director', 'Vice President, Academic Affairs', 'Vice President, Finance and Administration', 'General Counsel'
#  - Texas A&M Health Science Center: 'Senior Vice President', 'Associate Vice President, Faculty and Academic Affairs', 'Associate Vice President, Finance and Administration', 'Associate Vice President, Governmental and Public Affairs'
#  - Texas A&M University At Galveston: 'Chief Operations Officer', 'Vice President', 'Chief Academic Officer (Interim)', 'Vice President, Academic Affairs'
#  - University Of Minnesota: 'Regent', 'Regent', 'Regent', 'Regent'
#  - University Of Wisconsin Waukesha: 'Dean', 'Assistant Dean, Student Services (Interim)', 'Director, Continuing Education (Interim)', 'Director, Library and Media Services'
#  - University System Of Ohio: 'Ex Officio Regent', 'Ex Officio Regent', 'Vice Chair', 'Regent'
