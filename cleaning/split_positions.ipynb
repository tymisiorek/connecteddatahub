# %%
data_path = r'C:\Projects\connecteddatahub\data'

# %%
import pandas as pd
from pathlib import Path
from typing import List, Optional
import os

# %% [markdown]
# Word bank of positions that appear in the data:

# %%
POSITION_BANK = [
    "President", "Chancellor", "Provost", "Director", "Dean", "Controller",
    "Trustee", "Member", "Regent", "Chairman", "Overseer", "Assistant",
    "Librarian", "Secretary", "Chaplain", "Minister", "Treasurer",
    "Senior Counsel", "General Counsel", "Legal Counsel", "University Counsel",
    "College Counsel", "Special Counsel", "Corporation Counsel",
    "Corporate Counsel", "Officer", "Chief", "Professor", "Commissioner",
    "Fellow", "Chairperson", "Manager", "Clergy", "Coordinator", "Auditor",
    "Governor", "Representative", "Stockbroker", "Advisor", "Commandant",
    "Rector", "Attorney", "Curator", "Clerk", "Department Head", "Pastor",
    "Head", "Comptroller", "Deputy", "Inspector General", "Instructor",
    "Registrar", "Ombuds", "Administrator", "Liaison",
    "Administrative Associate", "Webmaster", "Specialist",
    "University Planner", "Architect",
]

# %%
data_path = r"C:\Projects\connecteddatahub\data"
years = ["1999","2000","2005","2007","2008","2009","2010","2011","2013","2018",]
# years = ['1999']

# %% [markdown]
# **Position Splitting Logic:**
#
# 1. Traverse backwards through the positions, checking for delimiters:
# 2. Check **And** first because this is the delimiter that will be used last every time
# 3. Then commas and semicolon – semicolon is a rare delimiter but does occur
# 4. Do not split if the format is something like “Dean, Office of the Provost”, because this is actually one position
# 5. Run this multiple times to account for positions needing to be split multiple times

# %%
def contains_position(text: str) -> bool:
    """Return True iff any word from POSITION_BANK appears in *text*."""
    return any(title in text for title in POSITION_BANK)

    
def count_appearances(text: str) -> int:
    """How many distinct bank titles appear (substring match)."""
    return sum(1 for title in POSITION_BANK if title in text)


def all_split_indices(text: str, sep: str) -> list[int]:
    """Return a list of all positions where `sep` occurs in `text`."""
    idxs = []
    start = 0
    while True:
        i = text.find(sep, start)
        if i < 0:
            return idxs
        idxs.append(i)
        start = i + len(sep)

def split_position_rows(df: pd.DataFrame) -> pd.DataFrame:
    new_rows = []
    for _, row in df.iterrows():
        pos = (str(row["Position"]) if not pd.isna(row["Position"]) else "").title()
        split_done = False

        for sep in ("And", ";", ","):
            # Try this delimiter up to three times
            for _ in range(3):
                for idx in reversed(all_split_indices(pos, sep)):
                    left  = pos[:idx].strip()
                    right = pos[idx + len(sep):].strip()

                    #never split if the LHS has no known title
                    if not contains_position(left):
                        continue

                    #skip unwanted “office of the” fragments e.g 'Director, Office of the Provost" would split into 2, but this is just one
                    low = right.lower()
                    if ("office of the" in low or "to the" in low or "'s office" in low or "for the" in low) and count_appearances(right) < 2:
                        continue

                    #if both sides now both contain a title, accept the split
                    if _contains_position(right):
                        top = row.copy(); top["Position"] = left
                        bottom = row.copy(); bottom["Position"] = right
                        new_rows.extend((top, bottom))
                        split_done = True
                        break

                if split_done:
                    break
            if split_done:
                break
        if not split_done:
            new_rows.append(row)
    return pd.DataFrame(new_rows).reset_index(drop=True)

def apply_splitting_pipeline(df: pd.DataFrame) -> pd.DataFrame:
    df = split_position_rows(df)
    df = split_position_rows(df)
    df = split_position_rows(df)
    return df

# %%
for year in years:
    print(f"Processing: {year}")
    gpt_df = pd.read_csv(os.path.join(data_path, 'gpt_dataframes', f'{year}_gptDataframe.csv'))
    split_df = apply_splitting_pipeline(gpt_df)
    split_df.to_csv(os.path.join(data_path, 'cleaned_dataframes', 'split_positions', f'{year}_split_positions.csv'), index=False)
# Out:
# Processing: 1999
# Processing: 2000
# Processing: 2005
# Processing: 2007
# Processing: 2008
# Processing: 2009
# Processing: 2010
# Processing: 2011
# Processing: 2013
# Processing: 2018

# %%
'''Same pipeline as before but used for validation so keeps track of each split that is made and prints out the resultant splits:'''


def split_position_rows_validation(
    df: pd.DataFrame
) -> Tuple[pd.DataFrame, List[Dict[str, Any]]]:
    """
    Splits rows on delimiters (“And”, “;”, “,”) exactly as before,
    but also records each split into `splits`.
    """
    splits: List[Dict[str, Any]] = []
    new_rows = []

    for idx, row in df.iterrows():
        pos = (str(row["Position"]) if not pd.isna(row["Position"]) else "").title()
        original_pos = pos
        split_done = False

        for sep in ("And", ";", ","):
            # Try up to three nested splits
            for _ in range(3):
                for split_idx in reversed(all_split_indices(pos, sep)):
                    left  = pos[:split_idx].strip()
                    right = pos[split_idx + len(sep):].strip()

                    # never split if LHS has no known title
                    if not contains_position(left):
                        continue

                    # skip “office of…” fragments
                    low = right.lower()
                    if  ("office of the" in low or "to the" in low or "'s office" in low or "for the" in low) and count_appearances(right) < 2:
                        continue

                    # if RHS also contains a title, do the split
                    if contains_position(right):
                        top = row.copy();    top["Position"] = left
                        bot = row.copy();    bot["Position"] = right
                        new_rows.extend([top, bot])

                        # record it
                        splits.append({
                            "row_index": idx,
                            "original": original_pos,
                            "sep": sep,
                            "left": left,
                            "right": right
                        })

                        split_done = True
                        break
                if split_done:
                    break
            if split_done:
                break

        if not split_done:
            new_rows.append(row)

    return pd.DataFrame(new_rows).reset_index(drop=True), splits

def apply_splitting_pipeline_validation(
    df: pd.DataFrame
) -> Tuple[pd.DataFrame, List[Dict[str, Any]]]:
    all_splits: List[Dict[str, Any]] = []
    df1, s1 = split_position_rows_validation(df)
    all_splits.extend(s1)
    df2, s2 = split_position_rows_validation(df1)
    all_splits.extend(s2)
    df3, s3 = split_position_rows_validation(df2)
    all_splits.extend(s3)
    return df3, all_splits

# %%
year = years[0]
gpt_df = pd.read_csv(os.path.join(data_path, 'gpt_dataframes', f'{year}_gptDataframe.csv'))
split_df, split_events = apply_splitting_pipeline_validation(gpt_df)

print("Splits performed:")
for ev in split_events:
    print(
        f" • Row {ev['row_index']}: "
        f"“{ev['original']}” split on “{ev['sep']}” to "
        f"“{ev['left']}” | “{ev['right']}”"
    )
# Out:
# Splits performed:
#  • Row 3: “Vice Chancellor And President, Acu Foundation” split on “And” to “Vice Chancellor” | “President, Acu Foundation”
#  • Row 7: “Vice President And General Counsel” split on “And” to “Vice President” | “General Counsel”
#  • Row 27: “Vice Chairman And Secretary” split on “And” to “Vice Chairman” | “Secretary”
#  • Row 105: “Assistant Secretary To The Board Of Trustees And Special Assistant To The President” split on “And” to “Assistant Secretary To The Board Of Trustees” | “Special Assistant To The President”
#  • Row 111: “Vice President, Finance And Treasurer” split on “And” to “Vice President, Finance” | “Treasurer”
#  • Row 121: “Controller And Associate Treasurer” split on “And” to “Controller” | “Associate Treasurer”
#  • Row 147: “Vice President, Student Life And Community Relations And Dean Of Students” split on “And” to “Vice President, Student Life And Community Relations” | “Dean Of Students”
#  • Row 154: “Director, Graduate Studies And Associate Dean Of The College” split on “And” to “Director, Graduate Studies” | “Associate Dean Of The College”
#  • Row 162: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 169: “Director, Institutional Research And Planning And Secretary” split on “And” to “Director, Institutional Research And Planning” | “Secretary”
#  • Row 190: “Vice President, Academic Affairs And Dean Of Faculty” split on “And” to “Vice President, Academic Affairs” | “Dean Of Faculty”
#  • Row 199: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 220: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 235: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 236: “Vice President, Business And Finance And Treasurer” split on “And” to “Vice President, Business And Finance” | “Treasurer”
#  • Row 238: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 282: “Vice President, Administrative Services And Treasurer” split on “And” to “Vice President, Administrative Services” | “Treasurer”
#  • Row 295: “Chaplain And Protestant Campus Minister” split on “And” to “Chaplain” | “Protestant Campus Minister”
#  • Row 301: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 340: “Vice President And University Counsel” split on “And” to “Vice President” | “University Counsel”
#  • Row 343: “Vice President, Finance And Treasurer” split on “And” to “Vice President, Finance” | “Treasurer”
#  • Row 420: “President And Secretary Of The Corporation” split on “And” to “President” | “Secretary Of The Corporation”
#  • Row 422: “Vice President, Enrollment Services Dean” split on “,” to “Vice President” | “Enrollment Services Dean”
#  • Row 426: “Associate Vice President. Finance And Controller” split on “And” to “Associate Vice President. Finance” | “Controller”
#  • Row 476: “Vice President, Academics And Dean Of The Faculty” split on “And” to “Vice President, Academics” | “Dean Of The Faculty”
#  • Row 534: “Comptroller And Treasurer” split on “And” to “Comptroller” | “Treasurer”
#  • Row 536: “Senior Vice President And Provost” split on “And” to “Senior Vice President” | “Provost”
#  • Row 579: “Vice Provost And Dean Of The College” split on “And” to “Vice Provost” | “Dean Of The College”
#  • Row 599: “Assistant Treasurer And Student Regent” split on “And” to “Assistant Treasurer” | “Student Regent”
#  • Row 604: “Provost And Dean, Faculty” split on “And” to “Provost” | “Dean, Faculty”
#  • Row 605: “Assistant To The Provost And Director, Institutional Research And Planning” split on “And” to “Assistant To The Provost” | “Director, Institutional Research And Planning”
#  • Row 606: “Executive Vice President And Treasurer” split on “And” to “Executive Vice President” | “Treasurer”
#  • Row 607: “Assistant To The Executive Vice President And General Counsel” split on “And” to “Assistant To The Executive Vice President” | “General Counsel”
#  • Row 610: “Vice President, Religious Affairs And Director, Campus Ministry” split on “And” to “Vice President, Religious Affairs” | “Director, Campus Ministry”
#  • Row 620: “Director, Finance And Controller” split on “And” to “Director, Finance” | “Controller”
#  • Row 628: “Vice President, Public Affairs And Secretary” split on “And” to “Vice President, Public Affairs” | “Secretary”
#  • Row 631: “Vice Chancellor And Trustee” split on “And” to “Vice Chancellor” | “Trustee”
#  • Row 632: “Chancellor And Trustee” split on “And” to “Chancellor” | “Trustee”
#  • Row 638: “Executive Vice President And Treasurer” split on “And” to “Executive Vice President” | “Treasurer”
#  • Row 639: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 654: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 656: “Associate Provost And Vice President, Research” split on “And” to “Associate Provost” | “Vice President, Research”
#  • Row 657: “Associate Provost And Vice President, Student Affairs” split on “And” to “Associate Provost” | “Vice President, Student Affairs”
#  • Row 658: “Associate Provost And Vice Presidentuniversity Outreach” split on “And” to “Associate Provost” | “Vice Presidentuniversity Outreach”
#  • Row 669: “Dean And Director, Agricultural Experiment Station (Until December 31, 1998) (Acting)” split on “And” to “Dean” | “Director, Agricultural Experiment Station (Until December 31, 1998) (Acting)”
#  • Row 670: “Dean And Director, Agricultural Experiment Station (Beginning January 1, 1999)” split on “And” to “Dean” | “Director, Agricultural Experiment Station (Beginning January 1, 1999)”
#  • Row 675: “Dean And Associate Director, Agricultural Experiment Station” split on “And” to “Dean” | “Associate Director, Agricultural Experiment Station”
#  • Row 676: “Dean And Associate Director, Agricultural Experiment Station” split on “And” to “Dean” | “Associate Director, Agricultural Experiment Station”
#  • Row 680: “Dean And Associate Director, Agricultural Experiment Station” split on “And” to “Dean” | “Associate Director, Agricultural Experiment Station”
#  • Row 681: “Dean And Associate Director, Agricultural Experiment Station” split on “And” to “Dean” | “Associate Director, Agricultural Experiment Station”
#  • Row 696: “Assistant To The President And Budget Officer” split on “And” to “Assistant To The President” | “Budget Officer”
#  • Row 736: “Chancellor And Ex Officio Regent” split on “And” to “Chancellor” | “Ex Officio Regent”
#  • Row 760: “Vice President, Business And Finance And University Treasurer” split on “And” to “Vice President, Business And Finance” | “University Treasurer”
#  • Row 774: “Dean And Executive Vice President” split on “And” to “Dean” | “Executive Vice President”
#  • Row 800: “Executive Assistant And Director, Institutional Planning And Research” split on “And” to “Executive Assistant” | “Director, Institutional Planning And Research”
#  • Row 803: “Vice President, Academic Affairs And Dean, College” split on “And” to “Vice President, Academic Affairs” | “Dean, College”
#  • Row 806: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 811: “Director, Personnel And Legal Advisor” split on “And” to “Director, Personnel” | “Legal Advisor”
#  • Row 816: “Treasurer And Executive Committee Member” split on “And” to “Treasurer” | “Executive Committee Member”
#  • Row 836: “President, Ex Officio Trustee And Executive Committee Member” split on “And” to “President, Ex Officio Trustee” | “Executive Committee Member”
#  • Row 838: “Trustee And Executive Committee Member” split on “And” to “Trustee” | “Executive Committee Member”
#  • Row 840: “Secretary And Executive Committee Member” split on “And” to “Secretary” | “Executive Committee Member”
#  • Row 841: “Vice Chairman And Executive Committee Member” split on “And” to “Vice Chairman” | “Executive Committee Member”
#  • Row 849: “Trustee And Executive Committee Member” split on “And” to “Trustee” | “Executive Committee Member”
#  • Row 855: “Assistant Secretary And Executive Committee Member” split on “And” to “Assistant Secretary” | “Executive Committee Member”
#  • Row 858: “Executive Assistant And Professor, Educational Psychology” split on “And” to “Executive Assistant” | “Professor, Educational Psychology”
#  • Row 859: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 860: “Vice President, Business Affairs And Treasurer” split on “And” to “Vice President, Business Affairs” | “Treasurer”
#  • Row 886: “Vice President, Student Affairs And Director, Admission” split on “And” to “Vice President, Student Affairs” | “Director, Admission”
#  • Row 950: “Provost And Senior Vice President, Academic Affairs” split on “And” to “Provost” | “Senior Vice President, Academic Affairs”
#  • Row 957: “Associate Vice President And Dean” split on “And” to “Associate Vice President” | “Dean”
#  • Row 958: “Associate Vice President And Dean” split on “And” to “Associate Vice President” | “Dean”
#  • Row 960: “Associate Vice President And Dean” split on “And” to “Associate Vice President” | “Dean”
#  • Row 962: “Associate Vice President And Dean” split on “And” to “Associate Vice President” | “Dean”
#  • Row 964: “Associate Vice President And Dean” split on “And” to “Associate Vice President” | “Dean”
#  • Row 967: “Associate Vice President And Dean” split on “And” to “Associate Vice President” | “Dean”
#  • Row 975: “Dean And Associate Vice President, Undergraduate Studies” split on “And” to “Dean” | “Associate Vice President, Undergraduate Studies”
#  • Row 978: “Dean And Associate Vice President, Academic Services” split on “And” to “Dean” | “Associate Vice President, Academic Services”
#  • Row 979: “Dean And Associate Vice President, Research” split on “And” to “Dean” | “Associate Vice President, Research”
#  • Row 981: “Dean And Associate Vice President, Graduate Studies” split on “And” to “Dean” | “Associate Vice President, Graduate Studies”
#  • Row 982: “Dean And Associate Vice President” split on “And” to “Dean” | “Associate Vice President”
#  • Row 1029: “Vice President, Academic Affairs And Dean Of The Faculty” split on “And” to “Vice President, Academic Affairs” | “Dean Of The Faculty”
#  • Row 1034: “Vice President, Financial Affairs And Treasurer” split on “And” to “Vice President, Financial Affairs” | “Treasurer”
#  • Row 1036: “Secretary And Office Manager” split on “And” to “Secretary” | “Office Manager”
#  • Row 1053: “President And Ex Officio Fellow” split on “And” to “President” | “Ex Officio Fellow”
#  • Row 1091: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 1098: “Assistant Vice President And Director, Academic Scholarships And Financial Aid” split on “And” to “Assistant Vice President” | “Director, Academic Scholarships And Financial Aid”
#  • Row 1107: “Chaplain And Director, Denominational Ministries” split on “And” to “Chaplain” | “Director, Denominational Ministries”
#  • Row 1161: “Vice President And Director, Center For Education Abroad” split on “And” to “Vice President” | “Director, Center For Education Abroad”
#  • Row 1162: “Vice President, Academic Affairs And Dean Of The College” split on “And” to “Vice President, Academic Affairs” | “Dean Of The College”
#  • Row 1164: “Vice President, Finance And Treasurer” split on “And” to “Vice President, Finance” | “Treasurer”
#  • Row 1179: “Director, Finance And Controller” split on “And” to “Director, Finance” | “Controller”
#  • Row 1190: “President, Alumni Association And Ex Officio Trustee” split on “And” to “President, Alumni Association” | “Ex Officio Trustee”
#  • Row 1204: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 1222: “President, Women'S Board And Ex Officio Trustee” split on “And” to “President, Women'S Board” | “Ex Officio Trustee”
#  • Row 1227: “Vice President And Dean Of The College” split on “And” to “Vice President” | “Dean Of The College”
#  • Row 1230: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 1235: “Controller And Personnel Director” split on “And” to “Controller” | “Personnel Director”
#  • Row 1301: “Vice President, Academic Affairs And Dean Of The College” split on “And” to “Vice President, Academic Affairs” | “Dean Of The College”
#  • Row 1302: “Vice President, Administration And Treasurer” split on “And” to “Vice President, Administration” | “Treasurer”
#  • Row 1305: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 1344: “Provost And Senior Vice President” split on “And” to “Provost” | “Senior Vice President”
#  • Row 1366: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 1446: “Academic Vice President And Dean Of Faculties” split on “And” to “Academic Vice President” | “Dean Of Faculties”
#  • Row 1447: “Vice President, Finance And Business Affairs And Treasurer” split on “And” to “Vice President, Finance And Business Affairs” | “Treasurer”
#  • Row 1488: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 1509: “Provost And Dean, College Of Arts And Sciences” split on “And” to “Provost” | “Dean, College Of Arts And Sciences”
#  • Row 1510: “Provost, Medical Campus And Dean, School Of Medicine” split on “And” to “Provost, Medical Campus” | “Dean, School Of Medicine”
#  • Row 1512: “Vice President And Dean Of Students” split on “And” to “Vice President” | “Dean Of Students”
#  • Row 1513: “Vice President And General Counsel” split on “And” to “Vice President” | “General Counsel”
#  • Row 1518: “Vice President, Financial Affairs And Treasurer” split on “And” to “Vice President, Financial Affairs” | “Treasurer”
#  • Row 1525: “Dean, College Of Arts And Sciences And Provost Of The University” split on “And” to “Dean, College Of Arts And Sciences” | “Provost Of The University”
#  • Row 1545: “Dean, School Of Medicine And Provost” split on “And” to “Dean, School Of Medicine” | “Provost”
#  • Row 1548: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1550: “Executive Committee Member And Vice Chairman” split on “And” to “Executive Committee Member” | “Vice Chairman”
#  • Row 1554: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1556: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1559: “Vice President, Financial Affairs And Treasurer” split on “And” to “Vice President, Financial Affairs” | “Treasurer”
#  • Row 1560: “Executive Committee Member And Chairman” split on “And” to “Executive Committee Member” | “Chairman”
#  • Row 1571: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1574: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1575: “Executive Committee Member And Secretary” split on “And” to “Executive Committee Member” | “Secretary”
#  • Row 1576: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1577: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1582: “Executive 1 Committee Member And Trustee” split on “And” to “Executive 1 Committee Member” | “Trustee”
#  • Row 1583: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1584: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1587: “Chancellor, Executive Committee Member And Trustee” split on “And” to “Chancellor, Executive Committee Member” | “Trustee”
#  • Row 1588: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1595: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1596: “President, Executive Committee Member And Trustee” split on “And” to “President, Executive Committee Member” | “Trustee”
#  • Row 1597: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 1599: “Vice President, Finance And Administration And Treasurer” split on “And” to “Vice President, Finance And Administration” | “Treasurer”
#  • Row 1657: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 1681: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 1698: “Associate Provost And Dean” split on “And” to “Associate Provost” | “Dean”
#  • Row 1702: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 1728: “Executive Assistant And Associate Vice President, University Affairs” split on “And” to “Executive Assistant” | “Associate Vice President, University Affairs”
#  • Row 1730: “Provost And Senior Vice President, Academic Affairs” split on “And” to “Provost” | “Senior Vice President, Academic Affairs”
#  • Row 1734: “Executive Vice President And Chief Operating Officer” split on “And” to “Executive Vice President” | “Chief Operating Officer”
#  • Row 1736: “Vice President And University Treasurer” split on “And” to “Vice President” | “University Treasurer”
#  • Row 1737: “Vice President And General Counsel” split on “And” to “Vice President” | “General Counsel”
#  • Row 1783: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 1799: “Vice President, Academic Affairs And Dean” split on “And” to “Vice President, Academic Affairs” | “Dean”
#  • Row 1848: “Assistant To The President, General Counsel And Secretary” split on “And” to “Assistant To The President, General Counsel” | “Secretary”
#  • Row 1861: “Assistant Advancement Vice President And Director, Men'S Athletics” split on “And” to “Assistant Advancement Vice President” | “Director, Men'S Athletics”
#  • Row 1863: “Assistant Advancement Vice President, University Relations And Executive Director, Alumni Association” split on “And” to “Assistant Advancement Vice President, University Relations” | “Executive Director, Alumni Association”
#  • Row 1881: “Associate Dean And Librarian” split on “And” to “Associate Dean” | “Librarian”
#  • Row 1903: “Provost And Executive Vice President” split on “And” to “Provost” | “Executive Vice President”
#  • Row 1906: “Senior Vice President, Finance And Administration And Chief Financial Officer” split on “And” to “Senior Vice President, Finance And Administration” | “Chief Financial Officer”
#  • Row 1908: “Vice President And General Counsel” split on “And” to “Vice President” | “General Counsel”
#  • Row 1909: “Vice President And University Controller” split on “And” to “Vice President” | “University Controller”
#  • Row 1913: “Assistant Vice President And Budget Director” split on “And” to “Assistant Vice President” | “Budget Director”
#  • Row 1928: “President And Fellow” split on “And” to “President” | “Fellow”
#  • Row 1980: “Treasurer And Chief Financial Officer” split on “And” to “Treasurer” | “Chief Financial Officer”
#  • Row 1985: “Chief Advancement Officer And Secretary Of The College” split on “And” to “Chief Advancement Officer” | “Secretary Of The College”
#  • Row 2000: “President, Alumni Association And Ex Officio Trustee” split on “And” to “President, Alumni Association” | “Ex Officio Trustee”
#  • Row 2020: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 2027: “Associate Vice President, Academic Affairs And Director, Graduate Studies” split on “And” to “Associate Vice President, Academic Affairs” | “Director, Graduate Studies”
#  • Row 2047: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 2050: “Chairperson Emeritus And Trustee” split on “And” to “Chairperson Emeritus” | “Trustee”
#  • Row 2065: “Associate Vice President, Finance, Assistant Secretary And Ex Officio Trustee” split on “And” to “Associate Vice President, Finance, Assistant Secretary” | “Ex Officio Trustee”
#  • Row 2068: “Chairman Emeritus And Trustee” split on “And” to “Chairman Emeritus” | “Trustee”
#  • Row 2110: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 2129: “Vice President And Provost” split on “And” to “Vice President” | “Provost”
#  • Row 2130: “Vice President And Director. Jet Propulsion Laboratory” split on “And” to “Vice President” | “Director. Jet Propulsion Laboratory”
#  • Row 2139: “Treasurer And Chief Financial Officer” split on “And” to “Treasurer” | “Chief Financial Officer”
#  • Row 2151: “Executive Committee Chairman And Trustee” split on “And” to “Executive Committee Chairman” | “Trustee”
#  • Row 2155: “Chairman And Chief Executive Officer” split on “And” to “Chairman” | “Chief Executive Officer”
#  • Row 2225: “President And Regent” split on “And” to “President” | “Regent”
#  • Row 2232: “Chairman And Chief Executive Officer” split on “And” to “Chairman” | “Chief Executive Officer”
#  • Row 2240: “President And Chief Executive Officer” split on “And” to “President” | “Chief Executive Officer”
#  • Row 2293: “President And Member” split on “And” to “President” | “Member”
#  • Row 2338: “Senior Vice Chancellor And Acting Chief Of Staff” split on “And” to “Senior Vice Chancellor” | “Acting Chief Of Staff”
#  • Row 2373: “Acting Associate Vice President, Academic Resources, Planning And Administration And Director, Institutional Research And Planning” split on “And” to “Acting Associate Vice President, Academic Resources, Planning And Administration” | “Director, Institutional Research And Planning”
#  • Row 2397: “Provost And Vice President” split on “And” to “Provost” | “Vice President”
#  • Row 2398: “Assistant To The Provost And Vice President And Faculty Affairs Specialist” split on “And” to “Assistant To The Provost And Vice President” | “Faculty Affairs Specialist”
#  • Row 2403: “Vice President, University Advancement And Executive Director, Cal State Bakersfield Foundation” split on “And” to “Vice President, University Advancement” | “Executive Director, Cal State Bakersfield Foundation”
#  • Row 2404: “Associate Vice President And Dean, Undergraduate Studies” split on “And” to “Associate Vice President” | “Dean, Undergraduate Studies”
#  • Row 2416: “Provost And Vice President” split on “And” to “Provost” | “Vice President”
#  • Row 2418: “Vice Provost, Academic Affairs And Dean” split on “And” to “Vice Provost, Academic Affairs” | “Dean”
#  • Row 2426: “Associate Vice President, Student Affairs And Director” split on “And” to “Associate Vice President, Student Affairs” | “Director”
#  • Row 2448: “Vice President, University Advancement And Assistant Vice President, University And Government Relations” split on “And” to “Vice President, University Advancement” | “Assistant Vice President, University And Government Relations”
#  • Row 2449: “Associate Vice President And Dean, Graduate Studies” split on “And” to “Associate Vice President” | “Dean, Graduate Studies”
#  • Row 2452: “Associate Vice President, Student Life And Director, University Student Union” split on “And” to “Associate Vice President, Student Life” | “Director, University Student Union”
#  • Row 2474: “Acting President And Ex Officio Advisor” split on “And” to “Acting President” | “Ex Officio Advisor”
#  • Row 2482: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2490: “Dean, Learning And Technology And Director, Academic Innovation Center” split on “And” to “Dean, Learning And Technology” | “Director, Academic Innovation Center”
#  • Row 2493: “Associate Dean And Director, University Health And Counseling” split on “And” to “Associate Dean” | “Director, University Health And Counseling”
#  • Row 2494: “Executive Director, Federal Programs And Judicial Affairs Officer” split on “And” to “Executive Director, Federal Programs” | “Judicial Affairs Officer”
#  • Row 2509: “Chief Information And Technology Officer (Acting)” split on “And” to “Chief Information” | “Technology Officer (Acting)”
#  • Row 2525: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2547: “Provost And Senior Vice President, Academic Affairs” split on “And” to “Provost” | “Senior Vice President, Academic Affairs”
#  • Row 2551: “Associate Vice President, Academic Affairs And Dean” split on “And” to “Associate Vice President, Academic Affairs” | “Dean”
#  • Row 2565: “Assistant Vice President, Sponsored Programs And Government Relations Liaison” split on “And” to “Assistant Vice President, Sponsored Programs” | “Government Relations Liaison”
#  • Row 2583: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2604: “Vice President, Academic Affairs And Provost” split on “And” to “Vice President, Academic Affairs” | “Provost”
#  • Row 2610: “Associate Vice President, Academic Planninginstruction And Assessment And Dean” split on “And” to “Associate Vice President, Academic Planninginstruction And Assessment” | “Dean”
#  • Row 2617: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2639: “Vice President, Academic Affairs And Provost” split on “And” to “Vice President, Academic Affairs” | “Provost”
#  • Row 2653: “Dean And University Librarian” split on “And” to “Dean” | “University Librarian”
#  • Row 2697: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2700: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 2702: “Associate Vice President, Academic Affairs And Dean, Graduate Studies” split on “And” to “Associate Vice President, Academic Affairs” | “Dean, Graduate Studies”
#  • Row 2706: “Senior Director, Enrollment Services And Director, Admissions And Records” split on “And” to “Senior Director, Enrollment Services” | “Director, Admissions And Records”
#  • Row 2707: “Senior Director, Retention Services And Director, Counseling, Career Development And Academic Support Services” split on “And” to “Senior Director, Retention Services” | “Director, Counseling, Career Development And Academic Support Services”
#  • Row 2735: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2748: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2761: “Director, Planned Giving And Legislative Liaison” split on “And” to “Director, Planned Giving” | “Legislative Liaison”
#  • Row 2785: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2788: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 2811: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 2858: “Chancellor, Secretary, Treasurer And Ex Officio Trustee” split on “And” to “Chancellor, Secretary, Treasurer” | “Ex Officio Trustee”
#  • Row 2863: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 2905: “Vice President, Academic Affairs And Provost” split on “And” to “Vice President, Academic Affairs” | “Provost”
#  • Row 2907: “Vice President, Business And Treasurer” split on “And” to “Vice President, Business” | “Treasurer”
#  • Row 2972: “Vice President, Academic Affairs And Provost (Acting)” split on “And” to “Vice President, Academic Affairs” | “Provost (Acting)”
#  • Row 2974: “Vice President, Resource Management And Treasurer” split on “And” to “Vice President, Resource Management” | “Treasurer”
#  • Row 3020: “Vice President And Treasurer” split on “And” to “Vice President” | “Treasurer”
#  • Row 3030: “Secretary, Board Of Trustees” split on “,” to “Secretary” | “Board Of Trustees”
#  • Row 3050: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 3072: “Vice President, Applied Research And Director, Carnegie Mellon Research Institute” split on “And” to “Vice President, Applied Research” | “Director, Carnegie Mellon Research Institute”
#  • Row 3101: “Vice President, Business And Administration And Trustee” split on “And” to “Vice President, Business And Administration” | “Trustee”
#  • Row 3111: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 3141: “Faculty Senate Chairman And Ex Officio Trustee” split on “And” to “Faculty Senate Chairman” | “Ex Officio Trustee”
#  • Row 3196: “Associate Vice President, Advancement And Senior Planned Giving Officer” split on “And” to “Associate Vice President, Advancement” | “Senior Planned Giving Officer”
#  • Row 3208: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 3236: “Associate Provost And Dean, Graduate Studies” split on “And” to “Associate Provost” | “Dean, Graduate Studies”
#  • Row 3247: “Associate Vice President, Finance And Administration And Controller” split on “And” to “Associate Vice President, Finance And Administration” | “Controller”
#  • Row 3262: “Associate Dean And Director, Residency And Career Planning” split on “And” to “Associate Dean” | “Director, Residency And Career Planning”
#  • Row 3270: “Clinical Professor, Ophthalmology And Trustee” split on “And” to “Clinical Professor, Ophthalmology” | “Trustee”
#  • Row 3303: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 3320: “Vice President, Finance And Treasurer” split on “And” to “Vice President, Finance” | “Treasurer”
#  • Row 3329: “Controller And Assistant Treasurer” split on “And” to “Controller” | “Assistant Treasurer”
#  • Row 3332: “University Chaplain And Director, Campus Ministry” split on “And” to “University Chaplain” | “Director, Campus Ministry”
#  • Row 3333: “Secretary Of The Board Of Trustees, Secretary Of The University And Chief Of Staff” split on “And” to “Secretary Of The Board Of Trustees, Secretary Of The University” | “Chief Of Staff”
#  • Row 3359: “Chancellor And Ex Officio Trustee” split on “And” to “Chancellor” | “Ex Officio Trustee”
#  • Row 3387: “Provost And Dean Of The College” split on “And” to “Provost” | “Dean Of The College”
#  • Row 3423: “Chairman Emeritus And Trustee” split on “And” to “Chairman Emeritus” | “Trustee”
#  • Row 3433: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 3446: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 3477: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 3506: “Executive Assistant To The President And Assistant Secretary To The Board” split on “And” to “Executive Assistant To The President” | “Assistant Secretary To The Board”
#  • Row 3507: “Vice President, Academic Affairs And Dean Of The College” split on “And” to “Vice President, Academic Affairs” | “Dean Of The College”
#  • Row 3534: “Executive Assistant To The President And Assistant Secretary” split on “And” to “Executive Assistant To The President” | “Assistant Secretary”
#  • Row 3543: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 3550: “Provost, Senior Vice President And Dean Of The Faculty” split on “And” to “Provost, Senior Vice President” | “Dean Of The Faculty”
#  • Row 3551: “Vice Provost And Dean, Graduate Studies” split on “And” to “Vice Provost” | “Dean, Graduate Studies”
#  • Row 3552: “Vice President And Dean, School Of Law” split on “And” to “Vice President” | “Dean, School Of Law”
#  • Row 3553: “Vice President, Registrar And Dean, Enrollment Services” split on “And” to “Vice President, Registrar” | “Dean, Enrollment Services”
#  • Row 3557: “Dean And Vice President” split on “And” to “Dean” | “Vice President”
#  • Row 3639: “President And Director” split on “And” to “President” | “Director”
#  • Row 3680: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 3698: “Vice President, Academic Affairs And Dean Of The College” split on “And” to “Vice President, Academic Affairs” | “Dean Of The College”
#  • Row 3703: “Dean, Enrollment Services And Registrar” split on “And” to “Dean, Enrollment Services” | “Registrar”
#  • Row 3706: “Director, Development And Special Assistant, Governmental Affairs” split on “And” to “Director, Development” | “Special Assistant, Governmental Affairs”
#  • Row 3741: “Vice Chancellor, Legal Affairs And General Counsel (Acting)” split on “And” to “Vice Chancellor, Legal Affairs” | “General Counsel (Acting)”
#  • Row 3769: “Provost And Senior Vice President, Academic Affairs” split on “And” to “Provost” | “Senior Vice President, Academic Affairs”
#  • Row 3774: “Vice President, Student Development And Dean Of Students” split on “And” to “Vice President, Student Development” | “Dean Of Students”
#  • Row 3775: “Assistant Vice President And Director, Campus Facilities And Operations” split on “And” to “Assistant Vice President” | “Director, Campus Facilities And Operations”
#  • Row 3776: “Assistant Vice President And Treasurer” split on “And” to “Assistant Vice President” | “Treasurer”
#  • Row 3796: “Provost And Vice President, Academic Affairs (Acting)” split on “And” to “Provost” | “Vice President, Academic Affairs (Acting)”
#  • Row 3803: “Executive Director, Academic Information Technologies And Chief Librarian” split on “And” to “Executive Director, Academic Information Technologies” | “Chief Librarian”
#  • Row 3817: “Vice President, Academic Affairs And Provost” split on “And” to “Vice President, Academic Affairs” | “Provost”
#  • Row 3839: “Provost And Senior Vice President, Academic Affairs” split on “And” to “Provost” | “Senior Vice President, Academic Affairs”
#  • Row 3867: “Acting Provost, Acting Vice President, Academic Affairs And Vice President, Administration” split on “And” to “Acting Provost, Acting Vice President, Academic Affairs” | “Vice President, Administration”
#  • Row 3893: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 3917: “Provost And Senior Vice President, Academic Affairs” split on “And” to “Provost” | “Senior Vice President, Academic Affairs”
#  • Row 3927: “Director, Development And Executive Director, Lehman College Foundation” split on “And” to “Director, Development” | “Executive Director, Lehman College Foundation”
#  • Row 3951: “Provost And Senior Vice President, Academic Affairs (Acting)” split on “And” to “Provost” | “Senior Vice President, Academic Affairs (Acting)”
#  • Row 3952: “Associate Provost And Assistant Vice President, Academic Planning And Programs” split on “And” to “Associate Provost” | “Assistant Vice President, Academic Planning And Programs”
#  • Row 3953: “Assistant Provost, Assistant Vice President And Director, Interdisciplinary Programs” split on “And” to “Assistant Provost, Assistant Vice President” | “Director, Interdisciplinary Programs”
#  • Row 3978: “Vice President, Academic Affairs And Provost” split on “And” to “Vice President, Academic Affairs” | “Provost”
#  • Row 3982: “Chief Financial Officer And Business Manager” split on “And” to “Chief Financial Officer” | “Business Manager”
#  • Row 3993: “Provost And Vice President, Academic Affairs (Acting)” split on “And” to “Provost” | “Vice President, Academic Affairs (Acting)”
#  • Row 3996: “Dean, Presidential Affairs” split on “,” to “Dean” | “Presidential Affairs”
#  • Row 4014: “Chairman, University Student Senate And Ex Officio Trustee” split on “And” to “Chairman, University Student Senate” | “Ex Officio Trustee”
#  • Row 4027: “Chairman, University Faculty Senate And Ex Officio Trustee” split on “And” to “Chairman, University Faculty Senate” | “Ex Officio Trustee”
#  • Row 4029: “President And Chief Executive Officer” split on “And” to “President” | “Chief Executive Officer”
#  • Row 4031: “Vice President And Dean, Admissions” split on “And” to “Vice President” | “Dean, Admissions”
#  • Row 4032: “Assistant And Office Manager” split on “And” to “Assistant” | “Office Manager”
#  • Row 4033: “Vice President And Dean Of The Faculty” split on “And” to “Vice President” | “Dean Of The Faculty”
#  • Row 4034: “Vice President And Dean Of Students” split on “And” to “Vice President” | “Dean Of Students”
#  • Row 4035: “Vice President And Treasurer” split on “And” to “Vice President” | “Treasurer”
#  • Row 4037: “Associate Vice President And Director, Development” split on “And” to “Associate Vice President” | “Director, Development”
#  • Row 4038: “Assistant Vice President And Directorhuman Resources” split on “And” to “Assistant Vice President” | “Directorhuman Resources”
#  • Row 4039: “Assistant Vice President And Director, Marketing And Public Relations” split on “And” to “Assistant Vice President” | “Director, Marketing And Public Relations”
#  • Row 4040: “Assistant Vice President And General Secretary” split on “And” to “Assistant Vice President” | “General Secretary”
#  • Row 4080: “President, Chief Executive Officer And Trustee” split on “And” to “President, Chief Executive Officer” | “Trustee”
#  • Row 4090: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 4097: “Associate Provost And Dean, Graduate Studies” split on “And” to “Associate Provost” | “Dean, Graduate Studies”
#  • Row 4107: “President, Undergraduate Student Government Association And Trustee” split on “And” to “President, Undergraduate Student Government Association” | “Trustee”
#  • Row 4111: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 4140: “Associate Provost And Dean Of The College” split on “And” to “Associate Provost” | “Dean Of The College”
#  • Row 4141: “Associate Provost And Dean, Graduate Studies And Research” split on “And” to “Associate Provost” | “Dean, Graduate Studies And Research”
#  • Row 4160: “Executive Assistant To The President And Finance And Treasurer, Assistant Secretary” split on “And” to “Executive Assistant To The President And Finance” | “Treasurer, Assistant Secretary”
#  • Row 4166: “Controller And Assistant Treasurer” split on “And” to “Controller” | “Assistant Treasurer”
#  • Row 4176: “Senior Vice President, Business And Financial Affairs And Treasurer” split on “And” to “Senior Vice President, Business And Financial Affairs” | “Treasurer”
#  • Row 4179: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 4180: “Associate Vice President, Academic Affairs And Dean, Undergraduate Admission” split on “And” to “Associate Vice President, Academic Affairs” | “Dean, Undergraduate Admission”
#  • Row 4196: “Vice Chairman, President And Chief Executive Officer” split on “And” to “Vice Chairman, President” | “Chief Executive Officer”
#  • Row 4198: “Senior Vice President, Science And Technology And Chief Technical Officer” split on “And” to “Senior Vice President, Science And Technology” | “Chief Technical Officer”
#  • Row 4218: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 4222: “Senior Vice Provost, Academic Affairs And Chief Research Officer” split on “And” to “Senior Vice Provost, Academic Affairs” | “Chief Research Officer”
#  • Row 4223: “Senior Vice Provost, Academic Affairs And Dean, Undergraduate Studies” split on “And” to “Senior Vice Provost, Academic Affairs” | “Dean, Undergraduate Studies”
#  • Row 4295: “Provost And Senior Vice President, Academic And Student Affairs” split on “And” to “Provost” | “Senior Vice President, Academic And Student Affairs”
#  • Row 4300: “Vice Provost And Dean, College Of Graduate Studies And Research” split on “And” to “Vice Provost” | “Dean, College Of Graduate Studies And Research”
#  • Row 4313: “University Legal Counsel And Secretary To The Board Of Trustees” split on “And” to “University Legal Counsel” | “Secretary To The Board Of Trustees”
#  • Row 4321: “Dean And Vice Provost” split on “And” to “Dean” | “Vice Provost”
#  • Row 4327: “University Legal Counsel And Secretary” split on “And” to “University Legal Counsel” | “Secretary”
#  • Row 4350: “Vice President, Academic Affairs And Dean Of The Faculty” split on “And” to “Vice President, Academic Affairs” | “Dean Of The Faculty”
#  • Row 4352: “Associate Vice President, Finance And Treasurer” split on “And” to “Associate Vice President, Finance” | “Treasurer”
#  • Row 4353: “Assistant Vice President, Development And Alumni Relations And Director, Corporate And Foundation Relations” split on “And” to “Assistant Vice President, Development And Alumni Relations” | “Director, Corporate And Foundation Relations”
#  • Row 4370: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 4397: “Assistant To The President And Secretary Of The Board” split on “And” to “Assistant To The President” | “Secretary Of The Board”
#  • Row 4398: “Provost And Dean Of The Faculty” split on “And” to “Provost” | “Dean Of The Faculty”
#  • Row 4402: “Vice President, Finance And Treasurer Of The Board” split on “And” to “Vice President, Finance” | “Treasurer Of The Board”
#  • Row 4403: “Associate Vice President And Controller” split on “And” to “Associate Vice President” | “Controller”
#  • Row 4416: “Trustee And Executive Committee Member” split on “And” to “Trustee” | “Executive Committee Member”
#  • Row 4426: “Trustee And Executive Committee Member” split on “And” to “Trustee” | “Executive Committee Member”
#  • Row 4427: “President, Trustee And Executive Committee Member” split on “And” to “President, Trustee” | “Executive Committee Member”
#  • Row 4432: “Chairman And Executive Committee Chairman” split on “And” to “Chairman” | “Executive Committee Chairman”
#  • Row 4441: “Trustee And Executive Committee Member” split on “And” to “Trustee” | “Executive Committee Member”
#  • Row 4449: “Trustee And Executive Committee Member” split on “And” to “Trustee” | “Executive Committee Member”
#  • Row 4548: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 4554: “Acting Dean, Library And Information Services And Dean, School Of Engineering” split on “And” to “Acting Dean, Library And Information Services” | “Dean, School Of Engineering”
#  • Row 4566: “President And Bx Oficio Trustee” split on “And” to “President” | “Bx Oficio Trustee”
#  • Row 4568: “President And Ex Olicio Trustee” split on “And” to “President” | “Ex Olicio Trustee”
#  • Row 4585: “Director, Presidential Affairs” split on “,” to “Director” | “Presidential Affairs”
#  • Row 4616: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 4624: “Business Manager And Controller” split on “And” to “Business Manager” | “Controller”
#  • Row 4664: “Vice President And Dean, Student Affairs” split on “And” to “Vice President” | “Dean, Student Affairs”
#  • Row 4665: “Vice President, Academic Affairs And Dean Of Faculty (Acting)” split on “And” to “Vice President, Academic Affairs” | “Dean Of Faculty (Acting)”
#  • Row 4668: “Vice President, Academic Affairs And Dean Of Faculty” split on “And” to “Vice President, Academic Affairs” | “Dean Of Faculty”
#  • Row 4745: “President And Trustee (Acting)” split on “And” to “President” | “Trustee (Acting)”
#  • Row 4747: “President And Chief Executive Officer” split on “And” to “President” | “Chief Executive Officer”
#  • Row 4800: “Executive Assistant To The President And Secretary Of The College And Board” split on “And” to “Executive Assistant To The President” | “Secretary Of The College And Board”
#  • Row 4828: “President And Ex Officio Trustee” split on “And” to “President” | “Ex Officio Trustee”
#  • Row 4855: “Vice President, Business And Finance And Treasurer” split on “And” to “Vice President, Business And Finance” | “Treasurer”
#  • Row 4858: “Dean Of The College And Dean Of The Faculty” split on “And” to “Dean Of The College” | “Dean Of The Faculty”
#  • Row 4861: “Dean, Summer Session And Professor, Mathematics” split on “And” to “Dean, Summer Session” | “Professor, Mathematics”
#  • Row 4865: “Legal Counsel And General Secretary” split on “And” to “Legal Counsel” | “General Secretary”
#  • Row 4883: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 4890: “President, National Alumni Council And Trustee” split on “And” to “President, National Alumni Council” | “Trustee”
#  • Row 4898: “Vice President, Academic Affairs And Dean Of Faculty” split on “And” to “Vice President, Academic Affairs” | “Dean Of Faculty”
#  • Row 4902: “Vice President, Student Life And Dean Of Students” split on “And” to “Vice President, Student Life” | “Dean Of Students”
#  • Row 4904: “Assistant Vice President, Student Life And Director, Enrollment Management” split on “And” to “Assistant Vice President, Student Life” | “Director, Enrollment Management”
#  • Row 4922: “Chancellor And President” split on “And” to “Chancellor” | “President”
#  • Row 4923: “Vice Chancellor And Secretary” split on “And” to “Vice Chancellor” | “Secretary”
#  • Row 4925: “Assistant Vice Chancellor And Director, Internal Auditing” split on “And” to “Assistant Vice Chancellor” | “Director, Internal Auditing”
#  • Row 4930: “Provost And Academic Vice President” split on “And” to “Provost” | “Academic Vice President”
#  • Row 4931: “Vice Provost, Agriculture And University Outreach And Dean, College Of Agricultural Sciences” split on “And” to “Vice Provost, Agriculture And University Outreach” | “Dean, College Of Agricultural Sciences”
#  • Row 4939: “Dean And Vice Provost, Agriculture And University Outreach” split on “And” to “Dean” | “Vice Provost, Agriculture And University Outreach”
#  • Row 4986: “Secretary, Treasurer And Non- Voting Board Member” split on “And” to “Secretary, Treasurer” | “Non- Voting Board Member”
#  • Row 4989: “Board Member And Third Executive Committee Member” split on “And” to “Board Member” | “Third Executive Committee Member”
#  • Row 4994: “Deputy Secretary And Non-Voting Board Member” split on “And” to “Deputy Secretary” | “Non-Voting Board Member”
#  • Row 5000: “Board Member And Fourth Executive Committee Member” split on “And” to “Board Member” | “Fourth Executive Committee Member”
#  • Row 5003: “Provost And Dean Of Faculties” split on “And” to “Provost” | “Dean Of Faculties”
#  • Row 5006: “Vice President, Arts And Sciences And Dean, Faculty Of Arts And Sciences” split on “And” to “Vice President, Arts And Sciences” | “Dean, Faculty Of Arts And Sciences”
#  • Row 5009: “Vice President, Health Sciences And Dean, College Of Physicians And Surgeons” split on “And” to “Vice President, Health Sciences” | “Dean, College Of Physicians And Surgeons”
#  • Row 5011: “Vice President, Information Services And University Librarian” split on “And” to “Vice President, Information Services” | “University Librarian”
#  • Row 5016: “Treasurer And Controller” split on “And” to “Treasurer” | “Controller”
#  • Row 5030: “Assistant Dean And Director, Career Services” split on “And” to “Assistant Dean” | “Director, Career Services”
#  • Row 5033: “Dean And Vice President, Health Sciences” split on “And” to “Dean” | “Vice President, Health Sciences”
#  • Row 5039: “Assistant Dean And Director, Mba Career Services” split on “And” to “Assistant Dean” | “Director, Mba Career Services”
#  • Row 5061: “President And Trustee” split on “And” to “President” | “Trustee”
# ...
#  • Row 24882: “Alumni Association President And Ex Officio Trustee” split on “And” to “Alumni Association President” | “Ex Officio Trustee”
#  • Row 24895: “President, Professor, Political Science” split on “,” to “President” | “Professor, Political Science”
#  • Row 24911: “Executive Vice President And Chief Financial Officer” split on “And” to “Executive Vice President” | “Chief Financial Officer”
#  • Row 24913: “Acting Chief Academic Officer And Academic Dean” split on “And” to “Acting Chief Academic Officer” | “Academic Dean”
#  • Row 24943: “Chief Financial Officer, Treasurer And Secretary To The Board Of Trustees” split on “And” to “Chief Financial Officer, Treasurer” | “Secretary To The Board Of Trustees”
#  • Row 24947: “Executive Committee Member And Chairman” split on “And” to “Executive Committee Member” | “Chairman”
#  • Row 24948: “Executive Committee Member And Trustee” split on “And” to “Executive Committee Member” | “Trustee”
#  • Row 24954: “Executive Committee Member And Vice Chairman” split on “And” to “Executive Committee Member” | “Vice Chairman”
#  • Row 24963: “Vice President, Academic Affairs And Dean Of Faculty” split on “And” to “Vice President, Academic Affairs” | “Dean Of Faculty”
#  • Row 24967: “Dean, Chapel And Campus Pastor” split on “And” to “Dean, Chapel” | “Campus Pastor”
#  • Row 25043: “Assistant And Vice President, Information Technology Services” split on “And” to “Assistant” | “Vice President, Information Technology Services”
#  • Row 25045: “Academic Vice President And Provost” split on “And” to “Academic Vice President” | “Provost”
#  • Row 25063: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 25097: “Controller And Director, Budget” split on “And” to “Controller” | “Director, Budget”
#  • Row 25121: “Vice President, Financial Affairs And Treasurer” split on “And” to “Vice President, Financial Affairs” | “Treasurer”
#  • Row 25145: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 25166: “Vice President, Administration And Treasurer” split on “And” to “Vice President, Administration” | “Treasurer”
#  • Row 25188: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 25272: “Senior Vice President And Dean Of The College” split on “And” to “Senior Vice President” | “Dean Of The College”
#  • Row 25274: “Vice President And Director, Intercollegiate Athletics” split on “And” to “Vice President” | “Director, Intercollegiate Athletics”
#  • Row 25276: “Vice President, Student Affairs And Dean Of Students” split on “And” to “Vice President, Student Affairs” | “Dean Of Students”
#  • Row 25313: “Provost And Vice President, Academic Affairs” split on “And” to “Provost” | “Vice President, Academic Affairs”
#  • Row 25314: “Vice President, Administration, Treasurer And Secretary Of The Corporation” split on “And” to “Vice President, Administration, Treasurer” | “Secretary Of The Corporation”
#  • Row 25317: “Associate Vice President, Business Affairs And Director, Physical Plant” split on “And” to “Associate Vice President, Business Affairs” | “Director, Physical Plant”
#  • Row 25320: “Controller And Assistant Secretary” split on “And” to “Controller” | “Assistant Secretary”
#  • Row 25348: “President And Trustee” split on “And” to “President” | “Trustee”
#  • Row 25384: “Secretary And Treasurer” split on “And” to “Secretary” | “Treasurer”
#  • Row 25460: “Associate Vice President, Student Services And Dean Of Students” split on “And” to “Associate Vice President, Student Services” | “Dean Of Students”
#  • Row 25484: “Secretary And Treasurer” split on “And” to “Secretary” | “Treasurer”
#  • Row 25490: “Vice President And General Counsel” split on “And” to “Vice President” | “General Counsel”
#  • Row 25491: “Vice President And Secretary” split on “And” to “Vice President” | “Secretary”
#  • Row 25496: “Dean, Student Affairs And Director, Freshman Affairs” split on “And” to “Dean, Student Affairs” | “Director, Freshman Affairs”
#  • Row 25502: “Dean And Director, Yale Repertory Theatre” split on “And” to “Dean” | “Director, Yale Repertory Theatre”
#  • Row 25599: “President And Director” split on “And” to “President” | “Director”
#  • Row 25649: “President And Director” split on “And” to “President” | “Director”
#  • Row 25683: “President And Director” split on “And” to “President” | “Director”
#  • Row 25743: “President And Overseer” split on “And” to “President” | “Overseer”
#  • Row 25781: “President And Governor” split on “And” to “President” | “Governor”
#  • Row 25807: “President And Governor” split on “And” to “President” | “Governor”
#  • Row 25849: “President And Director” split on “And” to “President” | “Director”
#  • Row 895: “President, Ex Officio Trustee” split on “,” to “President” | “Ex Officio Trustee”
#  • Row 1714: “Chancellor, Executive Committee Member” split on “,” to “Chancellor” | “Executive Committee Member”
#  • Row 1726: “President, Executive Committee Member” split on “,” to “President” | “Executive Committee Member”
#  • Row 1992: “Assistant To The President, General Counsel” split on “,” to “Assistant To The President” | “General Counsel”
#  • Row 2226: “Associate Vice President, Finance, Assistant Secretary” split on “,” to “Associate Vice President, Finance” | “Assistant Secretary”
#  • Row 2574: “Assistant To The Provost And Vice President” split on “And” to “Assistant To The Provost” | “Vice President”
#  • Row 3070: “Chancellor, Secretary, Treasurer” split on “,” to “Chancellor, Secretary” | “Treasurer”
#  • Row 3568: “Secretary Of The Board Of Trustees, Secretary Of The University” split on “,” to “Secretary Of The Board Of Trustees” | “Secretary Of The University”
#  • Row 3796: “Provost, Senior Vice President” split on “,” to “Provost” | “Senior Vice President”
#  • Row 3802: “Vice President, Registrar” split on “,” to “Vice President” | “Registrar”
#  • Row 4132: “Acting Provost, Acting Vice President, Academic Affairs” split on “,” to “Acting Provost” | “Acting Vice President, Academic Affairs”
#  • Row 4224: “Assistant Provost, Assistant Vice President” split on “,” to “Assistant Provost” | “Assistant Vice President”
#  • Row 4368: “President, Chief Executive Officer” split on “,” to “President” | “Chief Executive Officer”
#  • Row 4456: “Treasurer, Assistant Secretary” split on “,” to “Treasurer” | “Assistant Secretary”
#  • Row 4496: “Vice Chairman, President” split on “,” to “Vice Chairman” | “President”
#  • Row 4747: “President, Trustee” split on “,” to “President” | “Trustee”
#  • Row 5339: “Secretary, Treasurer” split on “,” to “Secretary” | “Treasurer”
#  • Row 6088: “Chairman, Board Of Advisors” split on “,” to “Chairman” | “Board Of Advisors”
#  • Row 6188: “Vice President, Dean Of The College” split on “,” to “Vice President” | “Dean Of The College”
#  • Row 6432: “Executive Director And Chief Executive Officer” split on “And” to “Executive Director” | “Chief Executive Officer”
#  • Row 6701: “Executive Assistant To The President, Vice President, Public Relations” split on “,” to “Executive Assistant To The President” | “Vice President, Public Relations”
#  • Row 6710: “Vice President, Treasurer” split on “,” to “Vice President” | “Treasurer”
#  • Row 6724: “Provost And Assistant Secretary” split on “And” to “Provost” | “Assistant Secretary”
#  • Row 8364: “Vice President, Academic Affairs, Dean Of The College” split on “,” to “Vice President, Academic Affairs” | “Dean Of The College”
#  • Row 8600: “Vice President, Human Resources And Secretary Of The University” split on “And” to “Vice President, Human Resources” | “Secretary Of The University”
#  • Row 8678: “Vice President And Chief Academic Officer, Main Campus” split on “And” to “Vice President” | “Chief Academic Officer, Main Campus”
#  • Row 8681: “Acting Dean And Vice President” split on “And” to “Acting Dean” | “Vice President”
#  • Row 9787: “Controller, Assistant Secretary” split on “,” to “Controller” | “Assistant Secretary”
#  • Row 9804: “Controller, Assistant Secretary” split on “,” to “Controller” | “Assistant Secretary”
#  • Row 10128: “Chairman, Hutton House Lectures Advisory Board” split on “,” to “Chairman” | “Hutton House Lectures Advisory Board”
#  • Row 10211: “Chancellor, C. W. Post Campus, Trustee” split on “,” to “Chancellor, C. W. Post Campus” | “Trustee”
#  • Row 10220: “Chancellor, Southampton Campus, Trustee” split on “,” to “Chancellor, Southampton Campus” | “Trustee”
#  • Row 10231: “Chancellor, Brooklyn Campus, Trustee” split on “,” to “Chancellor, Brooklyn Campus” | “Trustee”
#  • Row 10615: “Vice President, General Counsel” split on “,” to “Vice President” | “General Counsel”
#  • Row 10964: “Corporate Vice President, Assistant To The President” split on “,” to “Corporate Vice President” | “Assistant To The President”
#  • Row 11230: “Vice President, Finance And Treasurer” split on “And” to “Vice President, Finance” | “Treasurer”
#  • Row 12042: “Senior Vice President, Administration, Treasurer” split on “,” to “Senior Vice President, Administration” | “Treasurer”
#  • Row 12345: “Vice President, Dean” split on “,” to “Vice President” | “Dean”
#  • Row 12356: “Vice President, Dean” split on “,” to “Vice President” | “Dean”
#  • Row 12762: “Vice President, Administration And Finance, Chief Financial Officer” split on “And” to “Vice President, Administration” | “Finance, Chief Financial Officer”
#  • Row 12911: “Dean And Director, Agricultural Experiment Station” split on “And” to “Dean” | “Director, Agricultural Experiment Station”
#  • Row 13306: “Affiliation: Chairman, President” split on “,” to “Affiliation: Chairman” | “President”
#  • Row 13805: “Senior Vice President, Health Affairs, Chief Executive Officer, The Milton S. Hershey Medical Center” split on “,” to “Senior Vice President, Health Affairs” | “Chief Executive Officer, The Milton S. Hershey Medical Center”
#  • Row 13836: “Dean, Chief Executive Officer” split on “,” to “Dean” | “Chief Executive Officer”
#  • Row 14040: “Secretary, Board Of Trustees” split on “,” to “Secretary” | “Board Of Trustees”
#  • Row 14335: “Vice President And Chief Information” split on “And” to “Vice President” | “Chief Information”
#  • Row 14545: “President, Executive Committee Member” split on “,” to “President” | “Executive Committee Member”
#  • Row 14650: “President, Chief Executive Officer, Executive Committee Member” split on “,” to “President, Chief Executive Officer” | “Executive Committee Member”
#  • Row 14808: “Chairman, Ntid National Advisory Group” split on “,” to “Chairman” | “Ntid National Advisory Group”
#  • Row 14959: “Vice President, Rutgers University Foundation And Chief Development” split on “And” to “Vice President, Rutgers University Foundation” | “Chief Development”
#  • Row 15468: “Associate Vice President, Associate Dean” split on “,” to “Associate Vice President” | “Associate Dean”
#  • Row 15521: “Associate Professor, Integral Program, Secretary” split on “,” to “Associate Professor, Integral Program” | “Secretary”
#  • Row 15593: “Associate Vice President, Dean, School Of Business” split on “,” to “Associate Vice President” | “Dean, School Of Business”
#  • Row 15604: “Dean, Associate Vice President” split on “,” to “Dean” | “Associate Vice President”
#  • Row 16012: “Director, Financial Services For The Claremont Colleges, Controller,” split on “,” to “Director, Financial Services For The Claremont Colleges” | “Controller,”
#  • Row 16076: “President, Executive Committee Member” split on “,” to “President” | “Executive Committee Member”
#  • Row 16480: “Provost, Vice Chancellor, Academic Affairs” split on “,” to “Provost” | “Vice Chancellor, Academic Affairs”
#  • Row 16687: “Vice President, Academic Affairs And Executive Dean, Allied Health And Nursing” split on “And” to “Vice President, Academic Affairs” | “Executive Dean, Allied Health And Nursing”
#  • Row 16704: “Dean, Vice President, Academic Affairs” split on “,” to “Dean” | “Vice President, Academic Affairs”
#  • Row 16907: “Director, Judicial Affairs, Ombudsman” split on “,” to “Director, Judicial Affairs” | “Ombudsman”
#  • Row 17203: “Assistant Vice President, Presidential Initiatives” split on “,” to “Assistant Vice President” | “Presidential Initiatives”
#  • Row 17208: “Chief Executive Officer And Director, University Hospital” split on “And” to “Chief Executive Officer” | “Director, University Hospital”
#  • Row 17789: “Vice President, Treasurer” split on “,” to “Vice President” | “Treasurer”
#  • Row 17927: “Secretary, Board Of Trustees” split on “,” to “Secretary” | “Board Of Trustees”
#  • Row 17967: “President, Chancellor” split on “,” to “President” | “Chancellor”
#  • Row 17975: “Senior Vice President, Health Sciences Center And Chief Executive Officer, Temple University Hospital” split on “And” to “Senior Vice President, Health Sciences Center” | “Chief Executive Officer, Temple University Hospital”
#  • Row 17983: “Secretary, Board Of Trustees” split on “,” to “Secretary” | “Board Of Trustees”
#  • Row 18007: “Senior Vice President, Health Sciences Center, Chief Executive Officer” split on “,” to “Senior Vice President, Health Sciences Center” | “Chief Executive Officer”
#  • Row 18401: “Vice Chancellor, Finance And Business And Secretary” split on “And” to “Vice Chancellor, Finance And Business” | “Secretary”
#  • Row 18402: “Treasurer, Board Of Trustees” split on “,” to “Treasurer” | “Board Of Trustees”
#  • Row 18409: “Assistant Secretary, Board Of Trustees” split on “,” to “Assistant Secretary” | “Board Of Trustees”
#  • Row 19137: “Vice President And General Counsel” split on “And” to “Vice President” | “General Counsel”
#  • Row 21590: “Corporate Secretary, Board Of Regents” split on “,” to “Corporate Secretary” | “Board Of Regents”
#  • Row 21658: “Acting Chancellor, Vice Chancellor, Academic Affairs” split on “,” to “Acting Chancellor” | “Vice Chancellor, Academic Affairs”
#  • Row 21820: “Provost, Executive Vice President” split on “,” to “Provost” | “Executive Vice President”
#  • Row 22406: “Assistant Secretary, Board Of Trustees” split on “,” to “Assistant Secretary” | “Board Of Trustees”
#  • Row 22843: “Executive Secretary, Board Of Regents, Secretary Of The University” split on “,” to “Executive Secretary, Board Of Regents” | “Secretary Of The University”
#  • Row 22871: “Vice President, Health Affairs, Associate Provost” split on “,” to “Vice President, Health Affairs” | “Associate Provost”
#  • Row 23219: “Dean And Vice Provost, Marine Programs, Narragansett Bay Campus” split on “And” to “Dean” | “Vice Provost, Marine Programs, Narragansett Bay Campus”
#  • Row 23533: “Director, Community Services, President Emeritus” split on “,” to “Director, Community Services” | “President Emeritus”
#  • Row 23964: “Secretary, Board Of Trustees” split on “,” to “Secretary” | “Board Of Trustees”
#  • Row 24136: “Vice Provost, Academic Affairs, Associate Vice President, Undergraduate Academic And Student Affairs” split on “,” to “Vice Provost, Academic Affairs” | “Associate Vice President, Undergraduate Academic And Student Affairs”
#  • Row 25064: “Provost, Vice Chancellor” split on “,” to “Provost” | “Vice Chancellor”
#  • Row 25794: “President, Executive Committee Member” split on “,” to “President” | “Executive Committee Member”
#  • Row 25829: “Vice Chancellor, University Relations, General Counsel” split on “,” to “Vice Chancellor, University Relations” | “General Counsel”
#  • Row 25903: “Vice President, Chief Financial Officer” split on “,” to “Vice President” | “Chief Financial Officer”
#  • Row 26204: “President, Executive Committee Member” split on “,” to “President” | “Executive Committee Member”
#  • Row 26986: “Chief Financial Officer, Treasurer” split on “,” to “Chief Financial Officer” | “Treasurer”
#  • Row 27375: “Vice President, Administration, Treasurer” split on “,” to “Vice President, Administration” | “Treasurer”
#  • Row 3076: “Chancellor, Secretary” split on “,” to “Chancellor” | “Secretary”
#  • Row 14697: “President, Chief Executive Officer” split on “,” to “President” | “Chief Executive Officer”
#  • Row 22919: “Executive Secretary, Board Of Regents” split on “,” to “Executive Secretary” | “Board Of Regents”
