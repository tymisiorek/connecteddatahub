# %%
import pandas as pd
import os

# %%
years = ["1999","2000","2005","2007","2008","2009","2010","2011","2013","2018",]

data_path = r'C:\Projects\connecteddatahub\data\cleaned_dataframes\split_positions'

# %%
def mark_non_contiguous(df: pd.DataFrame):
    """
    Identify institutions whose rows in the DataFrame are not in a single contiguous
    block of indices. For each such institution, report the first gap detected.
    
    Prints:
      - Institution name
      - The pair of indices where the jump occurs (prev_index → next_index)
    
    Returns:
      List[Tuple[str, int, int]]: a list of (institution, prev_idx, next_idx) for each flagged group.
    """
    flagged = []
    
    # iterate groups without re‐sorting keys
    for inst, group in df.groupby("Institution", sort=False):
        idxs = sorted(group.index)
        # look for any gap > 1 between successive indices
        for prev_idx, next_idx in zip(idxs, idxs[1:]):
            if next_idx != prev_idx + 1:
                flagged.append((inst, prev_idx, next_idx))
                break  # only report the first gap per institution

    if flagged:
        print("\nNon-contiguous groups detected:")
        for inst, prev_idx, next_idx in flagged:
            print(f" - {inst}: gap between index {prev_idx} → {next_idx}")
    else:
        print("\nAll institution groups have contiguous indices.")
    
    return flagged

# %%
for year in years:
    print(f"Processing: {year}")
    gpt_df = pd.read_csv(os.path.join(data_path, f'{year}_split_positions.csv'))
    mark_non_contiguous(gpt_df)
# Out:
# Processing: 1999
#
# Non-contiguous groups detected:
#  - California State University System: gap between index 2524 → 3059
#  - City University Of New York: gap between index 4033 → 4301
#  - Queens College: gap between index 4260 → 14322
#  - College Of Charleston: gap between index 4844 → 4866
#  - College Of Mount St Joseph: gap between index 4865 → 4867
#  - Depaul University: gap between index 6018 → 6034
#  - Tennessee Board Of Regents: gap between index 6645 → 11501
#  - Harvard University: gap between index 8272 → 8291
#  - Louisiana State University System: gap between index 10304 → 10419
#  - Loyola University: gap between index 10638 → 10645
#  - Loyola University Chicago: gap between index 10644 → 10698
#  - University Of Montana Missoula: gap between index 11735 → 11747
#  - North Dakota University System: gap between index 12354 → 12361
#  - University Of Oregon: gap between index 13242 → 13247
#  - Pennsylvania State System Of Higher Education: gap between index 13405 → 13706
#  - Shippensburg University Of Pennsylvania: gap between index 13748 → 13777
#  - Southern Illinois University: gap between index 16516 → 16553
#  - State University System Of Florida: gap between index 17335 → 17713
#  - Texas A&M University System: gap between index 18276 → 18458
#  - Texas State University System: gap between index 18554 → 18664
#  - University Of Alaska System: gap between index 19352 → 19390
#  - University Of Arkansas System: gap between index 19449 → 19547
#  - University Of California System: gap between index 19565 → 19761
#  - University Of Colorado System: gap between index 19996 → 20045
#  - University Of Hawaii System: gap between index 20489 → 20529
#  - University Of Houston System: gap between index 20551 → 20631
#  - University Of Louisiana System: gap between index 21014 → 21094
#  - University Of Maine System: gap between index 21175 → 21255
#  - University Of Michigan: gap between index 21612 → 21640
#  - University Of Minnesota: gap between index 21694 → 21753
#  - University Of Nebraska System: gap between index 21906 → 21982
#  - University Of North Carolina System: gap between index 22140 → 22214
#  - University Of Tennessee System: gap between index 24049 → 24157
#  - University Of Texas System: gap between index 24210 → 24481
#  - University Of Washington: gap between index 24972 → 27306
#  - University Of Wisconsin System: gap between index 24978 → 25228
#  - University System Of Georgia: gap between index 25324 → 25553
#  - University System Of New Hampshire: gap between index 25741 → 25777
# Processing: 2000
#
# Non-contiguous groups detected:
#  - California State University System: gap between index 2625 → 3234
#  - City University Of New York Cuny: gap between index 4299 → 4566
#  - Colorado State University System: gap between index 5537 → 5600
#  - Indiana University System: gap between index 9347 → 9453
#  - Louisiana State University System: gap between index 10876 → 11015
#  - Montana University System: gap between index 12341 → 12452
#  - North Dakota University System: gap between index 13160 → 13257
#  - Oregon University System: gap between index 14042 → 14201
#  - Pennsylvania State System Of Higher Education: gap between index 14347 → 14748
#  - Shippensburg University Of Pennsylvania: gap between index 14680 → 14697
#  - Southern Illinois University System: gap between index 17848 → 17888
#  - State University Of New York System: gap between index 18177 → 18851
#  - State University System Of Florida: gap between index 18869 → 19306
#  - Texas A&M University System: gap between index 19910 → 20111
#  - Texas State University System: gap between index 20209 → 20322
#  - Nevada System Of Higher Education: gap between index 20998 → 21071
#  - University Of Alabama System: gap between index 21162 → 21241
#  - University Of Alaska System: gap between index 21265 → 21303
#  - University Of Arkansas System: gap between index 21364 → 21472
#  - University Of California System: gap between index 21496 → 21784
#  - University Of Colorado System: gap between index 22038 → 22098
#  - University Of Hawaii System: gap between index 22590 → 22638
#  - University Of Houston System: gap between index 22660 → 22787
#  - University Of Illinois: gap between index 22836 → 22908
#  - University Of Louisiana System: gap between index 23211 → 23304
#  - University Of Maine System: gap between index 23402 → 23499
#  - University Of Massachusetts System: gap between index 23524 → 23610
#  - University Of Miami: gap between index 23820 → 23863
#  - University Of Michigan: gap between index 23862 → 23873
#  - University Of Minnesota: gap between index 23958 → 24013
#  - University Of Missouri System: gap between index 24079 → 24165
#  - University Of Nebraska System: gap between index 24188 → 24274
#  - University Of North Carolina System: gap between index 24354 → 24933
#  - University Of Tennessee System: gap between index 26438 → 26552
#  - University Of Texas System: gap between index 26603 → 26916
#  - University Of Wisconsin System: gap between index 27449 → 27527
#  - University System Of Georgia: gap between index 27844 → 28089
#  - University System Of Maryland: gap between index 28109 → 28282
#  - University System Of New Hampshire: gap between index 28298 → 28335
# Processing: 2005
#
# Non-contiguous groups detected:
#  - California State University System: gap between index 2943 → 3738
#  - California State Polytechnic University Pomona: gap between index 3020 → 12663
#  - City University Of New York: gap between index 4890 → 5202
#  - Colorado State University System: gap between index 6323 → 6371
#  - Gustavus Adolphus College: gap between index 9842 → 9860
#  - Indiana University System: gap between index 10880 → 10986
#  - La Salle University: gap between index 11884 → 13194
#  - Louisiana State University System: gap between index 12536 → 12712
#  - Loyola University Chicago: gap between index 12966 → 12987
#  - Manhattan College: gap between index 13193 → 13195
#  - Mercer University: gap between index 13808 → 13828
#  - Mississippi Institutions Of Higher Learning: gap between index 14185 → 14457
#  - Montana University System: gap between index 14478 → 14614
#  - North Dakota University System: gap between index 15413 → 15592
#  - Oregon University System: gap between index 16492 → 16716
#  - Pennsylvania State System Of Higher Education: gap between index 16859 → 17332
#  - Slippery Rock University Of Pennsylvania: gap between index 17331 → 17333
#  - Purdue University: gap between index 17921 → 17978
#  - Southern Illinois University System: gap between index 20685 → 20745
#  - State University Of New York System: gap between index 21107 → 21856
#  - Texas A&M University System: gap between index 22509 → 22810
#  - Texas State University System: gap between index 22918 → 23072
#  - Texas Tech University System: gap between index 23097 → 23144
#  - University Of Alabama System: gap between index 24183 → 24287
#  - University Of Alaska System: gap between index 24316 → 24367
#  - University Of Arkansas System: gap between index 24447 → 24595
#  - University Of California System: gap between index 24636 → 25082
#  - University Of Colorado System: gap between index 25442 → 25545
#  - University Of Hawaii System: gap between index 26140 → 26189
#  - University Of Houston System: gap between index 26213 → 26344
#  - University Of Illinois System: gap between index 26401 → 26490
#  - University Of Louisiana System: gap between index 26941 → 27061
#  - University Of Maine System: gap between index 27162 → 27292
#  - University Of Massachusetts System: gap between index 27362 → 27391
#  - University Of Michigan: gap between index 27711 → 27754
#  - University Of Missouri System: gap between index 27903 → 28016
#  - University Of Nebraska System: gap between index 28040 → 28117
#  - University Of North Carolina System: gap between index 28241 → 28982
#  - University Of North Texas System: gap between index 29086 → 29163
#  - University Of Tennessee System: gap between index 30882 → 31010
#  - University Of Texas System: gap between index 31070 → 31489
#  - University Of Wisconsin System: gap between index 32175 → 32534
#  - University System Of Georgia: gap between index 32658 → 32987
#  - University System Of Maryland: gap between index 33012 → 33288
#  - University System Of New Hampshire: gap between index 33313 → 33358
# Processing: 2007
#
# Non-contiguous groups detected:
#  - Cornell University: gap between index 93 → 6588
#  - California State University System: gap between index 2783 → 3564
#  - City University Of New York: gap between index 4762 → 5144
#  - Colorado State University System: gap between index 6240 → 6299
#  - Florida Gulf Coast University: gap between index 8554 → 8651
#  - Indiana University System: gap between index 10875 → 10977
#  - Louisiana State University System: gap between index 12495 → 12539
#  - Louisiana State University At Eunice: gap between index 12570 → 12575
#  - Michigan State University: gap between index 13782 → 29626
#  - Mississippi Institutions Of Higher Learning: gap between index 14075 → 14351
#  - Montana University System: gap between index 14430 → 14570
#  - Nevada System Of Higher Education: gap between index 14955 → 15062
#  - North Dakota University System: gap between index 15527 → 15684
#  - Oregon University System: gap between index 16630 → 16864
#  - Pennsylvania State System Of Higher Education: gap between index 17033 → 17550
#  - Purdue University: gap between index 18070 → 18132
#  - University Of Pennsylvania: gap between index 18387 → 29795
#  - Seattle Pacific University: gap between index 20430 → 20456
#  - Southern Illinois University System: gap between index 20831 → 20892
#  - State University Of New York: gap between index 21204 → 21981
#  - Texas A&M University System: gap between index 22657 → 22963
#  - Texas State University System: gap between index 23072 → 23236
#  - Texas Tech University System: gap between index 23263 → 23308
#  - University Of Alabama System: gap between index 24247 → 24354
#  - University Of Alaska System: gap between index 24386 → 24435
#  - University Of Arkansas System: gap between index 24517 → 24675
#  - University Of California System: gap between index 24716 → 25168
#  - University Of Colorado System: gap between index 25542 → 25646
#  - University Of Hawaii System: gap between index 26245 → 26298
#  - University Of Houston System: gap between index 26321 → 26453
#  - University Of Illinois System: gap between index 26509 → 26597
#  - University Of Louisiana System: gap between index 27036 → 27153
#  - University Of Maine System: gap between index 27255 → 27391
#  - University Of Massachusetts System: gap between index 27464 → 27601
#  - University Of Michigan: gap between index 27903 → 27947
#  - University Of Minnesota: gap between index 28019 → 28078
#  - University Of Missouri System: gap between index 28101 → 28217
#  - University Of Nebraska System: gap between index 28238 → 28347
#  - University Of Nebraska At Kearney: gap between index 28294 → 28313
#  - University Of North Carolina System: gap between index 28444 → 29246
#  - University Of North Texas System: gap between index 29361 → 29432
#  - University Of Notre Dame: gap between index 29625 → 29627
#  - University Of Tennessee System: gap between index 31187 → 31322
#  - University Of Texas System: gap between index 31383 → 31844
#  - University Of Wisconsin System: gap between index 32567 → 32717
#  - University System Of Georgia: gap between index 33065 → 33373
#  - University Of West Georgia: gap between index 33372 → 33374
#  - University System Of Maryland: gap between index 33425 → 33720
#  - University System Of New Hampshire: gap between index 33748 → 33797
# Processing: 2008
#
# Non-contiguous groups detected:
#  - California State University System: gap between index 2951 → 3747
#  - City University Of New York: gap between index 4896 → 5212
#  - Colorado State University System: gap between index 6303 → 6365
#  - Columbia University: gap between index 6520 → 6539
#  - Duke University: gap between index 7689 → 7708
#  - Emerson College: gap between index 8217 → 8284
#  - Emory University: gap between index 8283 → 8295
#  - Indiana University System: gap between index 11057 → 11159
#  - Louisiana State University System: gap between index 12689 → 12741
#  - Mississippi Institutions Of Higher Learning: gap between index 14292 → 14573
#  - Montana University System: gap between index 14653 → 14791
#  - Nevada System Of Higher Education: gap between index 15244 → 15354
#  - North Dakota University System: gap between index 15807 → 15974
#  - Oregon University System: gap between index 17039 → 17266
#  - Pennsylvania State System Of Higher Education: gap between index 17425 → 17957
#  - Purdue University: gap between index 18538 → 18600
#  - Rutgers State University Of New Jersey: gap between index 19518 → 19549
#  - Southern Illinois University System: gap between index 21334 → 21400
#  - State University Of New York System: gap between index 21713 → 22491
#  - Texas A&M University System: gap between index 23217 → 23515
#  - Texas State University System: gap between index 23623 → 23772
#  - Sam Houston State University: gap between index 23734 → 23751
#  - Texas Tech University System: gap between index 23795 → 23870
#  - University Of Alabama System: gap between index 24772 → 24888
#  - University Of Alaska System: gap between index 24920 → 24968
#  - University Of Arkansas System: gap between index 25049 → 25214
#  - University Of California System: gap between index 25256 → 25713
#  - University Of Colorado System: gap between index 26109 → 26221
#  - University Of Hawaii System: gap between index 26804 → 26860
#  - University Of Houston System: gap between index 26884 → 27015
#  - University Of Illinois: gap between index 27076 → 27164
#  - University Of Louisiana System: gap between index 27619 → 27727
#  - University Of Maine System: gap between index 27844 → 27976
#  - University Of Massachusetts System: gap between index 28049 → 28183
#  - University Of Michigan: gap between index 28481 → 28525
#  - University Of Minnesota: gap between index 28599 → 28656
#  - University Of Missouri System: gap between index 28675 → 28795
#  - University Of Nebraska System: gap between index 28817 → 28929
#  - University Of Nebraska At Omaha: gap between index 28896 → 28910
#  - University Of North Carolina System: gap between index 29025 → 29810
#  - University Of North Texas System: gap between index 29925 → 29997
#  - University Of Tennessee System: gap between index 31721 → 31864
#  - University Of Texas System: gap between index 31921 → 32383
#  - University Of Wisconsin System: gap between index 33119 → 33491
#  - University System Of Georgia: gap between index 33633 → 33975
#  - University System Of Maryland: gap between index 34001 → 34310
#  - University System Of New Hampshire: gap between index 34336 → 34385
# Processing: 2009
#
# Non-contiguous groups detected:
#  - Auburn University: gap between index 821 → 823
#  - Boston College: gap between index 1828 → 1879
#  - Boston University: gap between index 1878 → 1889
#  - Brown University: gap between index 2411 → 7166
#  - California State University System: gap between index 2817 → 3588
#  - Colorado State University System: gap between index 6064 → 6124
#  - Drexel University: gap between index 7165 → 7185
#  - Duke University: gap between index 7361 → 7398
#  - Indiana University System: gap between index 10701 → 10821
#  - Louisiana State University System: gap between index 12374 → 12540
#  - Montana University System: gap between index 14300 → 14433
#  - Montana State University: gap between index 14336 → 14357
#  - Nevada System Of Higher Education: gap between index 14883 → 14990
#  - North Dakota University System: gap between index 15458 → 15627
#  - Oregon University System: gap between index 16663 → 16875
#  - Pennsylvania State System Of Higher Education: gap between index 17031 → 17555
#  - Purdue University: gap between index 18055 → 18122
#  - Rutgers State University Of New Jersey: gap between index 19067 → 19093
#  - State University Of New York: gap between index 21208 → 21890
#  - Texas A&M University System: gap between index 22662 → 22961
#  - Texas Tech University System: gap between index 23225 → 23300
#  - University Of Alabama System: gap between index 24221 → 24342
#  - University Of Alaska System: gap between index 24371 → 24419
#  - University Of Arkansas System: gap between index 24506 → 24656
#  - University Of California System: gap between index 24706 → 25180
#  - University Of Colorado System: gap between index 25569 → 25679
#  - University Of Hawaii System: gap between index 26273 → 26337
#  - University Of Houston System: gap between index 26361 → 26496
#  - University Of Illinois System: gap between index 26561 → 26648
#  - University Of Kentucky: gap between index 27042 → 27713
#  - University Of Louisiana System: gap between index 27111 → 27236
#  - University Of Maine System: gap between index 27336 → 27462
#  - University Of Massachusetts System: gap between index 27538 → 27674
#  - University Of Memphis: gap between index 27712 → 27733
#  - University Of Michigan: gap between index 27986 → 28030
#  - University Of Minnesota: gap between index 28106 → 28164
#  - University Of Missouri System: gap between index 28187 → 28307
#  - University Of Nebraska System: gap between index 28330 → 28441
#  - University Of North Carolina System: gap between index 28534 → 29178
#  - University Of North Texas System: gap between index 29290 → 29377
#  - University Of Tennessee System: gap between index 31091 → 31231
#  - University Of Texas System: gap between index 31285 → 31745
#  - University Of Wisconsin System: gap between index 32479 → 32853
#  - University System Of Georgia: gap between index 32991 → 33329
#  - University System Of Maryland: gap between index 33359 → 33662
#  - University System Of New Hampshire: gap between index 33687 → 33737
#  - Washington University: gap between index 34881 → 34887
# Processing: 2010
#
# Non-contiguous groups detected:
#  - Arizona Board Of Regents: gap between index 698 → 888
#  - Board Of Regents State Of Iowa: gap between index 1736 → 1964
#  - Brandeis University: gap between index 2382 → 2386
#  - Stanford University: gap between index 2385 → 20700
#  - California State University System: gap between index 3035 → 3776
#  - San Francisco State University: gap between index 3706 → 3708
#  - City University Of New York: gap between index 4868 → 5172
#  - Colorado State University System: gap between index 6234 → 6286
#  - Creighton University: gap between index 6752 → 6754
#  - Marquette University: gap between index 6753 → 12754
#  - Idaho State Board Of Education: gap between index 9942 → 10038
#  - Indiana University System: gap between index 10309 → 10442
#  - Kansas Board Of Regents: gap between index 11069 → 11237
#  - Louisiana State University System: gap between index 12038 → 12191
#  - Minnesota State Colleges And Universities System: gap between index 13425 → 13493
#  - Mississippi Institutions Of Higher Learning: gap between index 13562 → 13837
#  - Montana University System: gap between index 13910 → 14045
#  - Nevada System Of Higher Education: gap between index 14500 → 14602
#  - North Dakota University System: gap between index 15041 → 15210
#  - Oklahoma State System Of Higher Education: gap between index 15975 → 16147
#  - Oregon University System: gap between index 16323 → 16540
#  - Pennsylvania State System Of Higher Education: gap between index 16705 → 17063
#  - Purdue University: gap between index 17601 → 17690
#  - South Dakota Board Of Regents: gap between index 20342 → 20407
#  - Southern Illinois University System: gap between index 20458 → 20528
#  - State University Of New York System: gap between index 20824 → 21481
#  - State University System Of Florida: gap between index 21510 → 22006
#  - Tennessee Board Of Regents: gap between index 22613 → 22843
#  - Texas A&M University System: gap between index 22875 → 23155
#  - Texas State University System: gap between index 23260 → 23401
#  - Texas Tech University System: gap between index 23428 → 23502
#  - University Of Alabama System: gap between index 24439 → 24555
#  - University Of Alaska System: gap between index 24592 → 24635
#  - University Of Arkansas System: gap between index 24656 → 24812
#  - University Of California System: gap between index 24858 → 25314
#  - University Of Colorado System: gap between index 25627 → 25735
#  - University Of Hawaii System: gap between index 26258 → 26326
#  - University Of Houston System: gap between index 26355 → 26487
#  - University Of Illinois System: gap between index 26510 → 26600
#  - University Of Louisiana System: gap between index 26822 → 26953
#  - University Of Maine System: gap between index 27055 → 27182
#  - University Of Massachusetts System: gap between index 27251 → 27387
#  - University Of Massachusetts Amherst: gap between index 27286 → 27385
#  - University Of Michigan: gap between index 27616 → 27659
#  - University Of Minnesota: gap between index 27735 → 27795
#  - University Of Missouri System: gap between index 27819 → 27937
#  - University Of Nebraska System: gap between index 27960 → 28068
#  - University Of North Carolina System: gap between index 28159 → 28765
#  - University Of North Texas System: gap between index 28809 → 28892
#  - University Of Tennessee System: gap between index 30288 → 30427
#  - University Of Texas System: gap between index 30482 → 30942
#  - University Of Wisconsin System: gap between index 31515 → 31695
#  - University System Of Georgia: gap between index 32021 → 32379
#  - University System Of Maryland: gap between index 32410 → 32711
#  - University System Of New Hampshire: gap between index 32737 → 32789
#  - Utah System Of Higher Education: gap between index 32821 → 32965
# Processing: 2011
#
# Non-contiguous groups detected:
#  - Arizona Board Of Regents: gap between index 691 → 870
#  - Board Of Regents State Of Iowa: gap between index 1715 → 1938
#  - Boston College: gap between index 2048 → 2122
#  - California State University System: gap between index 2968 → 3699
#  - City University Of New York: gap between index 4791 → 5106
#  - Colorado State University System: gap between index 6112 → 6165
#  - Fairfield University: gap between index 7940 → 7974
#  - Fordham University: gap between index 8157 → 8185
#  - Idaho State Board Of Education: gap between index 9794 → 9885
#  - Indiana University System: gap between index 10134 → 10262
#  - Kansas Board Of Regents: gap between index 10887 → 11044
#  - Louisiana State University System: gap between index 11786 → 11935
#  - Marist College: gap between index 12502 → 12527
#  - Marquette University: gap between index 12526 → 12558
#  - Marylhurst University: gap between index 12713 → 12732
#  - Minnesota State Colleges And Universities System: gap between index 13135 → 13200
#  - Mississippi Institutions Of Higher Learning: gap between index 13275 → 13535
#  - Montana University System: gap between index 13610 → 13746
#  - Nevada System Of Higher Education: gap between index 14206 → 14304
#  - North Dakota University System: gap between index 14732 → 14900
#  - Oklahoma State System Of Higher Education: gap between index 15439 → 15601
#  - Oregon University System: gap between index 15774 → 16000
#  - Pennsylvania State System Of Higher Education: gap between index 16163 → 16517
#  - Purdue University: gap between index 17048 → 17111
#  - South Dakota Board Of Regents: gap between index 19742 → 19806
#  - Southern Illinois University: gap between index 19857 → 19927
#  - State University Of New York System: gap between index 20212 → 20846
#  - State University System Of Florida: gap between index 20877 → 21362
#  - Tennessee Board Of Regents: gap between index 21933 → 22160
#  - Texas A&M University System: gap between index 22194 → 22484
#  - Texas State University System: gap between index 22591 → 22731
#  - Texas Tech University System: gap between index 22757 → 22832
#  - University Of Alabama System: gap between index 23669 → 23776
#  - University Of Alaska System: gap between index 23811 → 23855
#  - University Of Arkansas System: gap between index 23876 → 24029
#  - University Of California System: gap between index 24074 → 24512
#  - University Of Colorado System: gap between index 24770 → 24877
#  - University Of Hawaii System: gap between index 25393 → 25462
#  - University Of Houston System: gap between index 25488 → 25588
#  - University Of Illinois System: gap between index 25610 → 25697
#  - University Of Louisiana System: gap between index 25917 → 26045
#  - University Of Maine System: gap between index 26145 → 26273
#  - University Of Massachusetts System: gap between index 26345 → 26481
#  - University Of Massachusetts Amherst: gap between index 26380 → 26399
#  - University Of Michigan: gap between index 26725 → 26770
#  - University Of Minnesota: gap between index 26850 → 26906
#  - University Of Missouri System: gap between index 26931 → 27049
#  - University Of Nebraska System: gap between index 27073 → 27180
#  - University Of North Carolina System: gap between index 27272 → 27701
#  - University Of North Texas System: gap between index 27898 → 27980
#  - University Of Tennessee System: gap between index 29336 → 29474
#  - University Of Texas System: gap between index 29531 → 30005
#  - University Of Wisconsin System: gap between index 30510 → 30889
#  - University System Of Georgia: gap between index 31013 → 31365
#  - University System Of Maryland: gap between index 31397 → 31692
#  - University System Of New Hampshire: gap between index 31717 → 31774
#  - University System Of Ohio: gap between index 31804 → 32323
#  - Utah System Of Higher Education: gap between index 32340 → 32482
# Processing: 2013
#
# Non-contiguous groups detected:
#  - Arizona Board Of Regents: gap between index 393 → 583
#  - Board Of Regents State Of Iowa: gap between index 1228 → 1404
#  - Boston University: gap between index 1618 → 1973
#  - Bucknell University: gap between index 1972 → 1974
#  - California State University System: gap between index 2161 → 2895
#  - California State University Fresno: gap between index 2434 → 2578
#  - City University Of New York: gap between index 3687 → 3974
#  - Colorado State University System: gap between index 4541 → 4593
#  - Harvard University: gap between index 6983 → 15741
#  - Idaho State Board Of Education: gap between index 7126 → 7219
#  - Indiana State University: gap between index 7376 → 22319
#  - Indiana University System: gap between index 7403 → 7538
#  - John Carroll University: gap between index 7855 → 13685
#  - Kansas Board Of Regents: gap between index 8081 → 8237
#  - Loma Linda University: gap between index 8430 → 8469
#  - Long Island University: gap between index 8468 → 8483
#  - Louisiana State University System: gap between index 8609 → 8651
#  - Minnesota State Colleges And Universities System: gap between index 9853 → 9914
#  - Mississippi Institutions Of Higher Learning: gap between index 9989 → 10241
#  - Montana University System: gap between index 10399 → 10537
#  - Nevada System Of Higher Education: gap between index 10710 → 10810
#  - North Dakota University System: gap between index 11174 → 11339
#  - Oklahoma State System Of Higher Education: gap between index 11806 → 11970
#  - Oregon University System: gap between index 12146 → 12370
#  - Pennsylvania State System Of Higher Education: gap between index 12577 → 12939
#  - Purdue University: gap between index 13400 → 13464
#  - Regis University: gap between index 13684 → 13686
#  - Saint Marys College Of California: gap between index 14826 → 14852
#  - South Dakota Board Of Regents: gap between index 15319 → 15387
#  - Southern Illinois University: gap between index 15444 → 15513
#  - Stanford University: gap between index 15740 → 15742
#  - State University Of New York System: gap between index 15767 → 16393
#  - State University Of New York At Geneseo: gap between index 16142 → 16166
#  - State University System Of Florida: gap between index 16426 → 16912
#  - Syracuse University: gap between index 17198 → 17200
#  - Tennessee Board Of Regents: gap between index 17371 → 17592
#  - Texas A&M University System: gap between index 17626 → 17908
#  - Texas State University System: gap between index 18019 → 18163
#  - Texas Tech University System: gap between index 18191 → 18268
#  - University Of Alabama System: gap between index 18754 → 18851
#  - University Of Alaska System: gap between index 18885 → 18930
#  - University Of Arkansas System: gap between index 18952 → 19114
#  - University Of California System: gap between index 19161 → 19596
#  - University Of Colorado System: gap between index 19817 → 19907
#  - University Of Hawaii System: gap between index 20405 → 20474
#  - University Of Houston System: gap between index 20499 → 20600
#  - University Of Illinois System: gap between index 20624 → 20714
#  - University Of Louisiana System: gap between index 20946 → 21083
#  - Mcneese State University: gap between index 21003 → 21016
#  - University Of Maine System: gap between index 21182 → 21309
#  - University Of Massachusetts System: gap between index 21382 → 21531
#  - University Of Massachusetts Amherst: gap between index 21418 → 21434
#  - University Of Michigan: gap between index 21763 → 21808
#  - University Of Missouri System: gap between index 21956 → 22079
#  - University Of Nebraska System: gap between index 22102 → 22208
#  - University Of North Carolina System: gap between index 22293 → 22874
#  - Appalachian State University: gap between index 22318 → 22320
#  - University Of North Texas System: gap between index 22919 → 23001
#  - University Of Tennessee System: gap between index 24400 → 24537
#  - University Of Texas System: gap between index 24590 → 25055
#  - University Of Wisconsin System: gap between index 25505 → 25887
#  - University System Of Georgia: gap between index 26008 → 26382
#  - University System Of Maryland: gap between index 26415 → 26648
#  - University System Of New Hampshire: gap between index 26757 → 26820
#  - University System Of Ohio: gap between index 26848 → 27408
#  - Utah System Of Higher Education: gap between index 27460 → 27603
# Processing: 2018
#
# Non-contiguous groups detected:
#  - Arizona Board Of Regents: gap between index 291 → 465
#  - Board Of Regents State Of Iowa: gap between index 1157 → 1311
#  - California State University System: gap between index 2051 → 2751
#  - City University Of New York: gap between index 3502 → 3810
#  - Clarkson University: gap between index 3988 → 3990
#  - Princeton University: gap between index 3989 → 12437
#  - Colorado State University System: gap between index 4394 → 4454
#  - Creighton University: gap between index 4781 → 4783
#  - Marquette University: gap between index 4782 → 8853
#  - Idaho State Board Of Education: gap between index 6851 → 6957
#  - Indiana University System: gap between index 7150 → 7302
#  - Kansas Board Of Regents: gap between index 7786 → 7943
#  - Louisiana State University System: gap between index 8291 → 8395
#  - Minnesota State Colleges And Universities System: gap between index 9416 → 9470
#  - Mississippi Institutions Of Higher Learning: gap between index 9550 → 9769
#  - Montana University System: gap between index 9915 → 10055
#  - Nevada System Of Higher Education: gap between index 10218 → 10305
#  - North Dakota University System: gap between index 10697 → 10850
#  - Oklahoma State System Of Higher Education: gap between index 11315 → 11460
#  - Pennsylvania State System Of Higher Education: gap between index 11901 → 12221
#  - Purdue University: gap between index 12681 → 12744
#  - Rutgers State University Of New Jersey: gap between index 13475 → 13486
#  - South Dakota Board Of Regents: gap between index 14542 → 14610
#  - Southern Illinois University: gap between index 14660 → 14724
#  - State University Of New York System: gap between index 14966 → 15570
#  - State University System Of Florida: gap between index 15602 → 15989
#  - Tennessee Board Of Regents: gap between index 16387 → 16613
#  - Texas A&M University System: gap between index 16648 → 16959
#  - Texas State University System: gap between index 17075 → 17214
#  - Texas Tech University System: gap between index 17239 → 17315
#  - Texas Wesleyan University: gap between index 17387 → 17418
#  - University Of Alabama System: gap between index 17820 → 17934
#  - University Of Alaska System: gap between index 17968 → 18019
#  - University Of Arkansas System: gap between index 18038 → 18206
#  - University Of California System: gap between index 18252 → 18667
#  - University Of Colorado System: gap between index 18880 → 18985
#  - University Of Hawaii System: gap between index 19416 → 19478
#  - University Of Houston: gap between index 19538 → 19594
#  - University Of Illinois System: gap between index 19616 → 19715
#  - University Of Louisiana System: gap between index 19934 → 20094
#  - University Of Maine System: gap between index 20193 → 20294
#  - University Of Massachusetts System: gap between index 20358 → 20510
#  - University Of Michigan: gap between index 20717 → 20758
#  - University Of Minnesota Crookston: gap between index 20831 → 20850
#  - University Of Missouri System: gap between index 20894 → 21036
#  - University Of Nebraska System: gap between index 21056 → 21175
#  - University Of North Carolina System: gap between index 21265 → 21807
#  - University Of North Texas System: gap between index 21855 → 21880
#  - University Of Tennessee System: gap between index 23332 → 23465
#  - University Of Texas System: gap between index 23517 → 23898
#  - University Of Wisconsin System: gap between index 24308 → 24448
#  - University System Of Georgia: gap between index 24743 → 24938
#  - University System Of Maryland: gap between index 25075 → 25345
#  - University System Of New Hampshire: gap between index 25421 → 25493
#  - Utah System Of Higher Education: gap between index 26046 → 26173
